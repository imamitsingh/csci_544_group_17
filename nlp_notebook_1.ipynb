# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install contractions
import pandas as pd
import os
import warnings
import re
import contractions
import nltk
warnings.filterwarnings("ignore", category=FutureWarning)
import re
from bs4 import BeautifulSoup
nltk.download('wordnet')
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii
#   Downloading anyascii-0.3.1-py3-none-any.whl (287 kB)
#      |████████████████████████████████| 287 kB 7.1 MB/s
# Collecting pyahocorasick
#   Downloading pyahocorasick-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 38.3 MB/s
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.1 contractions-0.1.73 pyahocorasick-1.4.4 textsearch-0.0.24
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
# complete_data.to_pickle("/content/gdrive/MyDrive/group_17/complete_data.pkl")
complete_data = pd.read_pickle("/content/gdrive/MyDrive/group_17/complete_data.pkl")
complete_data.head(2)
# Out:
#                                                POSTS    LABEL  TAGS
# 0  we rolled out enhancements to the godaddy paym...  protest    -1
# 1  the fact that the white supremacist nations of...  protest    -1

# %%
# unseen_complete_data.to_pickle("/content/gdrive/MyDrive/group_17/unseen_complete_data.pkl")
unseen_complete_data = pd.read_pickle("/content/gdrive/MyDrive/group_17/unseen_complete_data.pkl")
unseen_complete_data.drop(columns = ['index'], inplace = True)
unseen_complete_data.head(2)
# Out:
#                                                POSTS    LABEL  TAGS
# 0  does excel run on mac you bet so do word power...  excited     1
# 1  i am about to start a new role at capgemini an...  excited     1

# %%
df = pd.concat([complete_data, unseen_complete_data])
df.head(2)
# Out:
#                                                POSTS    LABEL  TAGS
# 0  we rolled out enhancements to the godaddy paym...  protest    -1
# 1  the fact that the white supremacist nations of...  protest    -1

# %%
df = df['TAGS']==1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-f3931d31482c> in <module>
# ----> 1 df = df(['TAGS']==1)
#
# TypeError: 'DataFrame' object is not callable

# %%
df_grouped = df.groupby(['TAGS', 'LABEL'])['LABEL'].count()

# %%
df_grouped.to_excel('df_grouped.xlsx')

# %%
import pandas
df_neg = pd.read_csv("/content/df_neg.csv")
df_neg
# Out:
#             Label  Count
# 0         anxiety    626
# 1      depression    777
# 2           grief    456
# 3    hiringfreeze    305
# 4       jobsearch    320
# 5          layoff    297
# 6         layoffs   2355
# 7       painpoint    375
# 8         protest    397
# 9        protests    372
# 10         racism    231
# 11      recession    310
# 12  recession2022    264
# 13       referral    121
# 14      rejection    404
# 15            sad    662
# 16   unemployment    302
# 17  womenequality    510
# 18    womensafety    427

# %%
df_pos = pd.read_csv("/content/df_pos.csv")
df_pos
# Out:
#              Label  Count
# 0          blessed    418
# 1          excited   1057
# 2              fun    695
# 3            funny    964
# 4         grateful    418
# 5    growthmindset    329
# 6            happy    364
# 7   healthymindset    491
# 8           hiring    464
# 9             lmao    403
# 10             lol    116
# 11          newjob    101
# 12   positivevibes    764
# 13      positivity    536

# %%
fig = px.pie(values=df_pos['Count'], names=df_pos['Label'])
fig.show()
# Out:
# <div>                            <div id="a1285fad-8887-47ea-8538-1db31126e489" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1285fad-8887-47ea-8538-1db31126e489")) {                    Plotly.newPlot(                        "a1285fad-8887-47ea-8538-1db31126e489",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["blessed","excited","fun","funny","grateful","growthmindset","happy","healthymindset","hiring","lmao","lol","newjob","positivevibes","positivity"],"legendgroup":"","name":"","showlegend":true,"values":[418,1057,695,964,418,329,364,491,464,403,116,101,764,536],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"sca ...

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.5.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)

# %%
import plotly.express as px
# df = px.data.gapminder().query("year == 2007").query("continent == 'Europe'")
# df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df, values='pop', names='country', title='Population of European continent')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3f9b7d6f-5af5-490c-9012-93d0848f625a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f9b7d6f-5af5-490c-9012-93d0848f625a")) {                    Plotly.newPlot(                        "3f9b7d6f-5af5-490c-9012-93d0848f625a",                        [{"alignmentgroup":"True","hovertemplate":"variable=LABEL<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"LABEL","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"LABEL","offsetgroup":"LABEL","orientation":"v","showlegend":true,"textposition":"auto","x":["protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest","protest ...

# %%
df.groupby('TAGS').first()
# Out:
#                                                   POSTS    LABEL
# TAGS
# -1    we rolled out enhancements to the godaddy paym...  protest
#  1    what if elon musk buys stackoverflow and charg...    funny

# %%
df['LABEL'].unique()
# Out:
# array(['protest', 'sad', 'funny', 'hiring', 'protests', 'referral',
#        'layoffs', 'womensafety', 'fun', 'anxiety', 'racism', 'recession',
#        'grief', 'layoff', 'excited', 'lmao', 'depression',
#        'womenequality', 'positivity', 'newjob', 'rejection',
#        'positivevibes', 'hiringfreeze', 'painpoint', 'grateful',
#        'jobsearch', 'unemployment', 'happy', 'blessed', 'lol',
#        'growthmindset', 'healthymindset', 'recession2022'], dtype=object)

# %%
df.groupby()

# %%
# amazon_reviews_data=pd.read_csv('/content/gdrive/MyDrive/Colab Notebooks/amazon_reviews_us_Jewelry_v1_00.tsv',sep='\t',on_bad_lines='skip')
# amazon_reviews_data.head()
# path = "/content/gdrive/MyDrive/Colab Notebooks/data/data/"
path = "/content/gdrive/MyDrive/group_17/train_val_data"
dir_list = os.listdir(path)
pd.set_option('display.max_colwidth', None)

# %%
all_lines_list=list()
labels_list=list()
for filename in dir_list:
    file_extension_val=filename.split('.')
    file_extension=file_extension_val[1]
    if(file_extension=='txt'):
        label=filename.split('_')
        label=label[2]
        label=label.split('.')
        label=label[0]
        labels_list.append(label)
        # with open("/content/gdrive/MyDrive/Colab Notebooks/data/data/"+filename, encoding='unicode_escape') as file_ptr:
        with open(path + "/" + filename, encoding='utf-8') as file_ptr:
            lines_temp = list()
            for line in file_ptr:
                if(line.strip()!="-----------------------------"):
                    lines_temp.append(line)
            all_lines_list.append(lines_temp)

# %%
def contr(post_text):
     posts_body_list=[]
     for r in post_text:
         decontract_posts_body = contractions.fix(r)
         r = ''.join(decontract_posts_body)
         r = re.sub("\s\s+", " ", r) # remove extra spaces
         posts_body_list.append(r)
     return posts_body_list

# %%
df_posts=pd.DataFrame()
labels_global_list=list()
label_index=0
for lst in all_lines_list:
    df_temp = pd.DataFrame(lst)
    df_posts=df_posts.append(df_temp,ignore_index=True,)
#     label_length=len(lst)
    for i in range(len(lst)):
        labels_global_list.append(labels_list[label_index])
    label_index=label_index+1
    
df_labels = pd.DataFrame(labels_global_list)

complete_data = pd.concat([df_posts, df_labels], axis=1)
complete_data.columns = ['POSTS', 'LABEL']

# convert to lowercase
complete_data['POSTS']=complete_data['POSTS'].str.lower()

# remove html content
complete_data['POSTS'] = complete_data['POSTS'].apply(lambda x: re.split('<[^<>]*>', str(x))[0])

# contraction
complete_data['POSTS']=contr(complete_data['POSTS'].values)

# remove non-alphabetical values
complete_data['POSTS'] = complete_data['POSTS'].replace('[^a-zA-Z ]', '', regex=True)

print("# of unique labels - ", len(complete_data['LABEL'].unique()))
print('Unique labels')
print(complete_data['LABEL'].unique())
# Out:
# # of unique labels -  33
# Unique labels
# ['protest (1)' 'sad (1)' 'funny (1)' 'hiring (1)' 'protests (1)'
#  'referral (1)' 'layoffs (1)' 'womensafety (1)' 'fun (1)' 'anxiety (1)'
#  'racism (1)' 'recession2022 (1)' 'grief (1)' 'layoff (1)' 'excited (1)'
#  'lmao (1)' 'depression (1)' 'womenequality (1)' 'positivity (1)'
#  'newjob (1)' 'rejection (1)' 'positivevibes (1)' 'hiringfreeze (1)'
#  'painpoint (1)' 'grateful (1)' 'jobsearch (1)' 'unemployment (1)'
#  'happy (1)' 'blessed (1)' 'lol (1)' 'excited' 'growthmindset (1)'
#  'healthymindset (1)']

# %%
complete_data['LABEL'] = complete_data['LABEL'].str.replace('[^a-zA-Z]', '')
complete_data['LABEL'].value_counts()
# Out:
# layoffs           2829
# excited           1498
# sad                857
# funny              756
# fun                726
# hiring             567
# jobsearch          559
# healthymindset     532
# womenequality      527
# rejection          521
# depression         510
# grief              498
# lmao               489
# womensafety        444
# blessed            438
# grateful           421
# protest            407
# painpoint          397
# positivity         389
# protests           385
# happy              378
# positivevibes      372
# anxiety            361
# growthmindset      336
# hiringfreeze       318
# recession          314
# layoff             299
# racism             239
# lol                141
# referral           129
# newjob             101
# unemployment         9
# Name: LABEL, dtype: int64

# %%
# add TAGS = [1, -1]
complete_data['TAGS']=np.where( (complete_data['LABEL']=='excited') | (complete_data['LABEL']=='hiring') | (complete_data['LABEL']=='positivity') | (complete_data['LABEL']=='positivevibes') | (complete_data['LABEL']=='grateful') | (complete_data['LABEL']=='newjob') | (complete_data['LABEL']=='blessed') | (complete_data['LABEL']=='happy') | (complete_data['LABEL']=='lmao') | (complete_data['LABEL']=='funny') | (complete_data['LABEL']=='fun') | (complete_data['LABEL']=='lol') | (complete_data['LABEL']=='growthmindset') | (complete_data['LABEL']=='healthymindset') | (complete_data['LABEL']=='humor') | (complete_data['LABEL']=='leadership') | (complete_data['LABEL']=='humour')
 , 1, -1)

# remove duplicates
print(complete_data.shape)
complete_data=complete_data.drop_duplicates(keep='last').reset_index()
print(complete_data.shape)

# remove nans
print(complete_data.shape)
complete_data['POSTS'].replace('', np.nan, inplace=True)
complete_data.dropna(subset=['POSTS'], inplace=True)
print(complete_data.shape)

# drop index
complete_data = complete_data.drop('index', axis=1)
# Out:
# (16747, 3)
# (14400, 4)
# (14400, 4)
# (14376, 4)

# %%
complete_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 we rolled out enhancements to the godaddy payments and studio platforms along with improvements to our domain investor experience check out how we are helping small businesses grow httpsprlymsub
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the fact that the white supremacist nations of the world feign authority over all is a real problem in my opinion as an american i can state unequivocally that we have no right to police the world when our priorities are so entirely out of line the same goes for the uk france germany canada australia and so onno child deserves this
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   if you want to know more about what is happening in iran right now please watch this video from abc by nicholas maher mahsaamini
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            together we are ending the use of neardrowning tests and saving animals from being forced to swim for their lives and we will not stop until these abusive and pointless experiments are a thing of the pastsome companies and universities completely stopped usingandor supporting others that usethe neardrowning test following actions taken by peta and our supporters including outreach by our scientists protests petaproposed shareholder resolutions and emails and calls from our supporters let us get more companies to ban the neardrowning test on animals use petas quick form to contact eli lilly todayhttpslnkdingnakfpgexperiments experiment experimentation science scienceandtechnology scientist company companies university universities highereducation protest demo demonstration shareholder shareholders shares email call animal animals animalrights animalwelfare animalcare crueltyfree saveanimals vegan govegan plantbased nonprofit nonprofitorganization advocate advocacy activist activism victory politicsandlaw socialissues
# 4  while i could not be there myself i was there in spirit cheering on the pregnant then screwed and the marchofthemummies over the past week as the over  parents and supporters took to the streets in london leeds manchester glasgow belfast cardiff exeter norwich bristol newcastle and birminghamthe coverage has looked spectacular truly raising awareness around the penalty of motherhood in the uk well done to joeli brearley and her incredibly talented teamdespite the uk being in desperate need of more people returning to work many mothers are prevented from returning to their careers by increasingly high childcare costs it is contributing to the gender pay gap  which increased in and looks as if it could do so again but that is a post for another day  and preventing women from making the most of their talents in the workplacewithout adequate funding from the government nurseries are forced to pass costs on to parents who increasingly cannot afford them new research shows that parents with the lowest incomes are having to spend three times as much on childcare as the richest the poorest parents spend  of their household earnings on childcare compared to  for the wealthiesthow utterly heartbreakinglow wages are making childcare an unattractive career option for nursery staff and childminders who are in seriously short supply while energy costs are heaping more pressure on nurseries to charge astronomical feesthis is why keeping the conversation going is vital the risk of burnout to those nursery staff and childminders is real the parents who have to take unpaid leave to be able to take care of their children are being put at an even greater disadvantage it is preventing mothers from getting back to work or progressing in their careers and widening the childcare poverty gapget involved and follow pregnant then screwed and find out about what they are doing on their website at the link in the commentsparentsatwork childcare womenatwork workingmum workingparents economysocietyworkingparentsworkingdads maternitypaypaternitypayprotestchange
#
#      LABEL  TAGS
# 0  protest    -1
# 1  protest    -1
# 2  protest    -1
# 3  protest    -1
# 4  protest    -1

# %%
complete_data['TAGS'].value_counts()
# Out:
# -1    8311
#  1    6065
# Name: TAGS, dtype: int64

# %%
complete_data.shape
# Out:
# (14376, 3)

# %%
complete_data['LABEL'].value_counts()
# Out:
# layoffs           2355
# excited            966
# fun                695
# sad                662
# funny              613
# womenequality      510
# healthymindset     491
# hiring             464
# grief              456
# depression         447
# womensafety        427
# blessed            418
# grateful           418
# rejection          404
# lmao               403
# protest            397
# painpoint          375
# protests           372
# happy              364
# positivity         347
# positivevibes      340
# growthmindset      329
# jobsearch          320
# anxiety            313
# recession          310
# hiringfreeze       305
# layoff             297
# racism             231
# referral           121
# lol                116
# newjob             101
# unemployment         9
# Name: LABEL, dtype: int64

# %%
unseen_complete_data['LABEL'].value_counts()
# Out:
# positivevibes    424
# funny            351
# depression       330
# anxiety          313
# unemployment     293
# recession2022    264
# positivity       189
# excited           91
# Name: LABEL, dtype: int64

# %%
unseen_complete_data['LABEL'].value_counts()

# %% [markdown]
# **NEGATIVE**: protests, racism, layoffs, depression, sad, layoff, recession2022,anxiety,  protest, grief, painpoint, unemployment, rejection, hiringfreeze
#
# **POSITIVE**: excited, hiring, positivity, positivevibes, grateful, newjob, blessed, happy, lmao, funny, fun, lol
#
# womenequality, womensafety, job search
#
# **ROBERTA**: NEG= anger+sad
#          POS= joy+optimism

# %% [markdown]
# **Tokenise & Split**

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
#max_features = 2000
#tokenizer = Tokenizer(num_words = max_features, )
tokenizer = Tokenizer()
tokenizer.fit_on_texts(complete_data['POSTS'].values)
X = tokenizer.texts_to_sequences(complete_data['POSTS'].values)
X = pad_sequences(X, padding = 'post' , maxlen=100)
Y = pd.get_dummies(complete_data['TAGS']).values
#Y= complete_data['TAGS']

vocab_size = len(tokenizer.word_index)+1

# %%
#Y_rus = pd.get_dummies(y_rus).values
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.25, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (10782, 100) (10782, 2)
# (3594, 100) (3594, 2)

# %% [markdown]
# **FastText Embeddings using pretrained embeddings (Facebook model)**

# %%
# !pip install fasttext
import fasttext
import fasttext.util
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: fasttext in /usr/local/lib/python3.7/dist-packages (0.9.2)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext) (57.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fasttext) (1.21.6)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext) (2.10.1)

# %%
# fasttext.util.download_model('en', if_exists='ignore')
# ft = fasttext.load_model('cc.en.300.bin')

# %%
# ft.save_model('/content/gdrive/MyDrive/Colab Notebooks/cc.en.100.bin')

# %%
model = fasttext.load_model('/content/gdrive/MyDrive/Colab Notebooks/cc.en.100.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
model.get_dimension()
# Out:
# 300

# %%
post_lst=complete_data['POSTS']
from tqdm import tqdm
word_tokenizer = nltk.WordPunctTokenizer()
word_tokens = [word_tokenizer.tokenize(sent) for sent in tqdm(post_lst)]
# Out:
# 100%|██████████| 14376/14376 [00:00<00:00, 31884.62it/s]

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
#max_features = 2000
#tokenizer = Tokenizer(num_words = max_features, )
tokenizer = Tokenizer()
tokenizer.fit_on_texts(complete_data['POSTS'].values)
X = tokenizer.texts_to_sequences(complete_data['POSTS'].values)
X = pad_sequences(X, padding = 'post' , maxlen=100)
Y = pd.get_dummies(complete_data['TAGS']).values
#Y= complete_data['TAGS']

vocab_size = len(tokenizer.word_index)+1

# %%
# from imblearn.under_sampling import RandomUnderSampler
# from collections import Counter
# rus = RandomUnderSampler(random_state=42, replacement=True)# fit predictor and target variable
# x_rus, y_rus = rus.fit_resample(X, Y)

# print('original dataset shape:', Counter(Y))
# print('Resample dataset shape', Counter(y_rus))
# Out:
# original dataset shape: Counter({-1: 8311, 1: 6065})
# Resample dataset shape Counter({-1: 6065, 1: 6065})

# %%
#Y_rus = pd.get_dummies(y_rus).values
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.25, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (10782, 100) (10782, 2)
# (3594, 100) (3594, 2)

# %%
embedding_matrix = np.zeros((vocab_size,300))
for word,i in tqdm(tokenizer.word_index.items()):
    embedding_value = model.get_word_vector(word)
    embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 92516/92516 [00:01<00:00, 54265.86it/s]

# %%
len(embedding_matrix),embedding_matrix.size
# Out:
# (92517, 27755100)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras import utils
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization


from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Bidirectional, Dropout
embid_dim = 300
lstm_out = 128
lstm_model = keras.Sequential()
lstm_model.add(Embedding(vocab_size, embid_dim, weights = [embedding_matrix] , trainable = False))
lstm_model.add(Bidirectional(LSTM(lstm_out, dropout=0.2)))
lstm_model.add(Dense(128, activation = 'relu'))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(64, activation = 'relu'))
lstm_model.add(Dense(2, activation = 'softmax'))  #if used pd.get dummies above
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 300)         27755100
#
#  bidirectional_1 (Bidirectio  (None, 256)              439296
#  nal)
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,235,678
# Trainable params: 480,578
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=10,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)
batch_size = 200
lstm_model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
history = lstm_model.fit(X_train, Y_train, epochs = 50, batch_size=batch_size, verbose = 1, callbacks=[early_stopping_monitor], validation_data =(X_test, Y_test))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 88s 2s/step - loss: 0.6250 - accuracy: 0.6491 - val_loss: 0.4887 - val_accuracy: 0.7660
# Epoch 2/50
# 54/54 [==============================] - 76s 1s/step - loss: 0.4625 - accuracy: 0.7876 - val_loss: 0.4331 - val_accuracy: 0.7927
# Epoch 3/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.4131 - accuracy: 0.8107 - val_loss: 0.3973 - val_accuracy: 0.8152
# Epoch 4/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.3796 - accuracy: 0.8254 - val_loss: 0.3931 - val_accuracy: 0.8116
# Epoch 5/50
# 54/54 [==============================] - 76s 1s/step - loss: 0.3658 - accuracy: 0.8306 - val_loss: 0.3884 - val_accuracy: 0.8297
# Epoch 6/50
# 54/54 [==============================] - 77s 1s/step - loss: 0.3412 - accuracy: 0.8472 - val_loss: 0.3650 - val_accuracy: 0.8392
# Epoch 7/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.3347 - accuracy: 0.8479 - val_loss: 0.3651 - val_accuracy: 0.8278
# Epoch 8/50
# 54/54 [==============================] - 76s 1s/step - loss: 0.3030 - accuracy: 0.8591 - val_loss: 0.3450 - val_accuracy: 0.8434
# Epoch 9/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.2891 - accuracy: 0.8659 - val_loss: 0.3482 - val_accuracy: 0.8356
# Epoch 10/50
# 54/54 [==============================] - 79s 1s/step - loss: 0.2837 - accuracy: 0.8694 - val_loss: 0.3477 - val_accuracy: 0.8375
# Epoch 11/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.2643 - accuracy: 0.8804 - val_loss: 0.3507 - val_accuracy: 0.8225
# Epoch 12/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.2522 - accuracy: 0.8866 - val_loss: 0.3409 - val_accuracy: 0.8456
# Epoch 13/50
# 54/54 [==============================] - 77s 1s/step - loss: 0.2462 - accuracy: 0.8856 - val_loss: 0.3388 - val_accuracy: 0.8456
# Epoch 14/50
# 54/54 [==============================] - 75s 1s/step - loss: 0.2444 - accuracy: 0.8915 - val_loss: 0.3472 - val_accuracy: 0.8383
# Epoch 15/50
# 54/54 [==============================] - 77s 1s/step - loss: 0.2331 - accuracy: 0.8968 - val_loss: 0.3436 - val_accuracy: 0.8492
# Epoch 16/50
# 54/54 [==============================] - 76s 1s/step - loss: 0.2149 - accuracy: 0.9023 - val_loss: 0.3283 - val_accuracy: 0.8478
# Epoch 17/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.2134 - accuracy: 0.9037 - val_loss: 0.3180 - val_accuracy: 0.8567
# Epoch 18/50
# 54/54 [==============================] - 78s 1s/step - loss: 0.2056 - accuracy: 0.9085 - val_loss: 0.3457 - val_accuracy: 0.8567
# Epoch 19/50
# 54/54 [==============================] - 75s 1s/step - loss: 0.1950 - accuracy: 0.9121 - val_loss: 0.3350 - val_accuracy: 0.8495
# Epoch 20/50
# 54/54 [==============================] - 77s 1s/step - loss: 0.1907 - accuracy: 0.9180 - val_loss: 0.3570 - val_accuracy: 0.8589
# Epoch 21/50
# 54/54 [==============================] - 76s 1s/step - loss: 0.1796 - accuracy: 0.9192 - val_loss: 0.3517 - val_accuracy: 0.8523
# Epoch 22/50
# 54/54 [==============================] - 77s 1s/step - loss: 0.1806 - accuracy: 0.9202 - val_loss: 0.3867 - val_accuracy: 0.8542
# Epoch 23/50
# 54/54 [==============================] - 75s 1s/step - loss: 0.1679 - accuracy: 0.9270 - val_loss: 0.3807 - val_accuracy: 0.8584
# Epoch 24/50
# 54/54 [==============================] - 77s 1s/step - loss: 0.1676 - accuracy: 0.9294 - val_loss: 0.3784 - val_accuracy: 0.8648
# Epoch 25/50
# 54/54 [==============================] - 77s 1s/step - loss: 0.1627 - accuracy: 0.9316 - val_loss: 0.3475 - val_accuracy: 0.8592
# Epoch 26/50
# 54/54 [==============================] - 76s 1s/step - loss: 0.1500 - accuracy: 0.9342 - val_loss: 0.3658 - val_accuracy: 0.8575
# Epoch 27/50
# 54/54 [==============================] - 77s 1s/step - loss: 0.1482 - accuracy: 0.9354 - val_loss: 0.3758 - val_accuracy: 0.8703

# %%
lstm_model.save('/content/gdrive/MyDrive/Colab Notebooks/')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn, lstm_cell_5_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %%
lstm_model = tf.keras.models.load_model('/content/gdrive/MyDrive/Colab Notebooks')

lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 300)         25990200
#
#  bidirectional (Bidirectiona  (None, 256)              439296
#  l)
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 26,470,778
# Trainable params: 480,578
# Non-trainable params: 25,990,200
# _________________________________________________________________

# %%
Y_test_new=[]
for val in Y_test:
  if val[0]==1:
    Y_test_new.append(0)
  else:
    Y_test_new.append(1)

# %%
from sklearn.metrics import classification_report

y_pred = lstm_model.predict(X_test, batch_size=64, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)

print(classification_report(Y_test_new, y_pred_bool))
# Out:
# 57/57 [==============================] - 20s 334ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88      2114
#            1       0.86      0.77      0.82      1480
#
#     accuracy                           0.86      3594
#    macro avg       0.86      0.84      0.85      3594
# weighted avg       0.86      0.86      0.86      3594

# %% [markdown]
# **Testing the model on completely new/unseen data**

# %%
path = "/content/gdrive/MyDrive/group_17/unseen_test_data"
dir_list = os.listdir(path)
pd.set_option('display.max_colwidth', None)

# %%
all_lines_list=list()
labels_list=list()
for filename in dir_list:
    file_extension_val=filename.split('.')
    file_extension=file_extension_val[1]
    if(file_extension=='txt'):
        label=filename.split('_')
        label=label[2]
        label=label.split('.')
        label=label[0]
        labels_list.append(label)
        # with open("/content/gdrive/MyDrive/Colab Notebooks/Unseen_test_data/"+filename, encoding='unicode_escape') as file_ptr:
        with open(path + "/" + filename, encoding='utf-8') as file_ptr:
            lines_temp = list()
            for line in file_ptr:
                if(line.strip()!="-----------------------------"):
                    lines_temp.append(line)
            all_lines_list.append(lines_temp)

# %%
df_posts=pd.DataFrame()
labels_global_list=list()
label_index=0
for lst in all_lines_list:
    df_temp = pd.DataFrame(lst)
    df_posts=df_posts.append(df_temp,ignore_index=True,)
#     label_length=len(lst)
    for i in range(len(lst)):
        labels_global_list.append(labels_list[label_index])
    label_index=label_index+1
    
df_labels = pd.DataFrame(labels_global_list)

# %%
unseen_complete_data = pd.concat([df_posts, df_labels], axis=1)
unseen_complete_data.columns = ['POSTS', 'LABEL']
unseen_complete_data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Does Excel run on Mac? You bet. So do Word, PowerPoint, and all the apps you need.\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I'm about to start a new role at Capgemini and containing myself is a real issue.Don't ask 😌#excited\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 New chapter. #excited\n
# 3     Flying away from the Nest and setting off for new adventures on the other side of the planet 🗺️This day marks a couple of important milestones:-         My first post ever on LinkedIn 🚀 (Is this really a milestone?)-         My last day working at Nestlé-         The beginning of a new and exciting journey 😍I am thrilled to announce that I’ll be moving to New Zealand as of February 2023 (#excited). Driven by the willingness to enrich ourselves as individuals, to go out of our comfort zone, to experience a new professional and personal environment, and to discover new outdoor experiences, my partner and I have decided to take that step. And why not?Since I graduated from ISIPCA in 2014, the past decade at Nestlé (wow, this sounds like a lot) which started with a 2-years internship has been incredibly rich and I feel very lucky for all the projects and experiences I went through. I met inspiring people and worked on innovative projects. From being part of the Nestlé R&D accelerator to the nesQino™️ journey, and plenty of other initiatives, I enjoyed the diversity of projects, activities, and challenges.The journey has also sometimes been punctuated with some doubts and questions, which were essential to go the extra mile. Those who know me know that I am always eager to learn new things. I don’t know yet what will come next, and I am very curious to see what the future will bring… The next two months will be busy organizing the move (and solving admin stuff), enjoying time with family and friends, recharging, and settling in New Zealand. I’ll be available for work as of February 2023 and I can’t wait to discover what New Zealand has to offer. I would love to start discussions about expatriation experiences, tips about New Zealand, potential work opportunities (including remote), …\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          #Excited about the great things to come from this partnership.  Gracias to my Omnicom Media Group familia (Geoffrey Calabrese, Kelly Metz, Amy Darwish) and TelevisaUnivision (Daniel Aversano, Richard Bertodatti) for making this happen! #multiculturalmarketing https://lnkd.in/eVpbW7CU\n
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2579                                                                                                                                                                                                                                                                                                                                                                                                                  Allowing Ourselves To Be Nurtured Let yourself be nurtured and loved.Let people be there for you.Allow yourself to be held when it would feel good.Let someone listen to you, support and encourage you when you need that.Receive comfort from someone's physical presence when you need that. Allow yourself to be supported emotionally and cared about.For too long, we've stood in the background, attending to the needs of others and claiming we have no needs of our own.We've shut off, for too long, the part of us that longs to be nurtured.It is time, now, to claim those needs, identify them, and understand that we deserve to have them met. What are our needs? What would feel good? What kinds of ways would we like others to nurture and support us?The clearer we can be about our needs, the greater the possibility they will be met.Hugs. A listening ear. Support. Encouragement.The physical and emotional presence of people who care about us.Doesn't that sound good? Tempting?No matter how old or successful we are,  we never outgrow our need for nurturing and love.Enjoyed reading this? Follow me on: https://bit.ly/3AqIY6k #couplegoals #love #loved #lovedogs #loveforever #loveislove #lovelive #lovely #lovemakeup #lovemylife #lovenature #lovequotes #lovers #loves #lovestory #lovethem #loveu #lovewhatyoudo #loveyou #loveyourbody #meditation #mindset #momlife #mylove #poetry #positivity #relationshipgoals\n
# 2580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Good morning 😊#goodmorning #goodlife #dontgiveup #win #motivational #motivationalquotes #motivationalspeaker #goodvibesonly #vibes #energy #positivemindset #positivity #sucessmindset #sucess #sucessful #quoteoftheday #quotesaboutlife #opportunites #opportunityseeker #growthopportunities #growth #goals #winner\n
# 2581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Shout out to all the men of REALSTA who despite all odds and obstacles paved the way for themselves in this over-ambitious world. May you get more strength and love. You are doing the best you can and we are all proud of you. Wishing you a very Happy International Men's Day!#internationalmensday #mensday #men #mensrights #meninist #mentoo #mgtow #mra #antifeminist #equality #antifeminism #feminism #redpill #mensmentalhealth #himtoo #mgtowisthefuture #november #equalrights #metoo #love #redpilled #mgtowforlife #meninism #boys #positivity #malepositivity\n
# 2582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              #inspiration #innovation #positivity #management #technology #success\n
# 2583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            On the latest episode of The Editing Podcast, Denise and Louise explain why they don’t share content they dislike and why it’s a good idea that you don’t, either. If you see something that doesn’t sit quite right with you, don’t spread it around — share something positive instead. 🌻Find out more about the hosts by visiting their websites. – Denise Cowle: https://lnkd.in/gzuAEwPA – Louise Harnby: https://lnkd.in/gV7wMsuZ#editing #podcast #positivity #theeditingpodcast\n
#
#            LABEL
# 0        excited
# 1        excited
# 2        excited
# 3        excited
# 4        excited
# ...          ...
# 2579  positivity
# 2580  positivity
# 2581  positivity
# 2582  positivity
# 2583  positivity
#
# [2584 rows x 2 columns]

# %%
#convert to lowercase
unseen_complete_data['POSTS']=unseen_complete_data['POSTS'].str.lower()

# %%
#remove html content
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].apply(lambda x: re.split('<[^<>]*>', str(x))[0])

# %%
def contr(post_text):
     posts_body_list=[]
     for r in post_text:
         decontract_posts_body = contractions.fix(r)
         r = ''.join(decontract_posts_body)
         r = re.sub("\s\s+", " ", r) # remove extra spaces
         posts_body_list.append(r)
     return posts_body_list

# %%
unseen_complete_data['POSTS']=contr(unseen_complete_data['POSTS'].values)

# %%
#remove non-alphabetical values
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].replace('[^a-zA-Z ]', '', regex=True)

# %%
import numpy as np
unseen_complete_data['TAGS']=np.where( (unseen_complete_data['LABEL']=='excited') | (unseen_complete_data['LABEL']=='hiring') | (unseen_complete_data['LABEL']=='positivity') | (unseen_complete_data['LABEL']=='positivevibes') | (unseen_complete_data['LABEL']=='grateful') | (unseen_complete_data['LABEL']=='newjob') | (unseen_complete_data['LABEL']=='blessed') | (unseen_complete_data['LABEL']=='happy') | (unseen_complete_data['LABEL']=='lmao') | (unseen_complete_data['LABEL']=='funny') | (unseen_complete_data['LABEL']=='fun') | (unseen_complete_data['LABEL']=='lol') , 1, -1)

# %%
unseen_complete_data=unseen_complete_data.drop_duplicates(keep='last').reset_index()

# %%
unseen_complete_data['POSTS'].replace('', np.nan, inplace=True)
unseen_complete_data.dropna(subset=['POSTS'], inplace=True)
unseen_complete_data
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 2257   2579
# 2258   2580
# 2259   2581
# 2260   2582
# 2261   2583
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 does excel run on mac you bet so do word powerpoint and all the apps you need
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i am about to start a new role at capgemini and containing myself is a real issuedo not ask excited
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           new chapter excited
# 3     flying away from the nest and setting off for new adventures on the other side of the planet this day marks a couple of important milestones my first post ever on linkedin  is this really a milestone my last day working at nestl the beginning of a new and exciting journey i am thrilled to announce that i will be moving to new zealand as of february  excited driven by the willingness to enrich ourselves as individuals to go out of our comfort zone to experience a new professional and personal environment and to discover new outdoor experiences my partner and i have decided to take that step and why notsince i graduated from isipca in  the past decade at nestl wow this sounds like a lot which started with a years internship has been incredibly rich and i feel very lucky for all the projects and experiences i went through i met inspiring people and worked on innovative projects from being part of the nestl rd accelerator to the nesqino journey and plenty of other initiatives i enjoyed the diversity of projects activities and challengesthe journey has also sometimes been punctuated with some doubts and questions which were essential to go the extra mile those who know me know that i am always eager to learn new things i do not know yet what will come next and i am very curious to see what the future will bring the next two months will be busy organizing the move and solving admin stuff enjoying time with family and friends recharging and settling in new zealand i will be available for work as of february  and i cannot wait to discover what new zealand has to offer i would love to start discussions about expatriation experiences tips about new zealand potential work opportunities including remote
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    excited about the great things to come from this partnership gracias to my omnicom media group familia geoffrey calabrese kelly metz amy darwish and televisaunivision daniel aversano richard bertodatti for making this happen multiculturalmarketing httpslnkdinevpbwcu
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 2257                                                                                                                                                                                                                                                                                                                                                                                           allowing ourselves to be nurturedlet yourself be nurtured and lovedlet people be there for youallow yourself to be held when it would feel goodlet someone listen to you support and encourage you when you need thatreceive comfort from someone is physical presence when you need that allow yourself to be supported emotionally and cared aboutfor too long we have stood in the background attending to the needs of others and claiming we have no needs of our ownwe have shut off for too long the part of us that longs to be nurturedit is time now to claim those needs identify them and understand that we deserve to have them metwhat are our needs what would feel good what kinds of ways would we like others to nurture and support usthe clearer we can be about our needs the greater the possibility they will be methugs a listening ear support encouragementthe physical and emotional presence of people who care about usdoes not that sound good temptingno matter how old or successful we are we never outgrow our need for nurturing and loveenjoyed reading this follow me on httpsbitlyaqiyk couplegoals love loved lovedogs loveforever loveislove lovelive lovely lovemakeup lovemylife lovenature lovequotes lovers loves lovestory lovethem loveu lovewhatyoudo loveyou loveyourbody meditation mindset momlife mylove poetry positivity relationshipgoals
# 2258                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning goodmorning goodlife dontgiveup win motivational motivationalquotes motivationalspeaker goodvibesonly vibes energy positivemindset positivity sucessmindset sucess sucessful quoteoftheday quotesaboutlife opportunites opportunityseeker growthopportunities growth goals winner
# 2259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                shout out to all the men of realsta who despite all odds and obstacles paved the way for themselves in this overambitious worldmay you get more strength and love you are doing the best you can and we are all proud of youwishing you a very happy international mens dayinternationalmensday mensday men mensrights meninist mentoo mgtow mra antifeminist equality antifeminism feminism redpill mensmentalhealthhimtoo mgtowisthefuture november equalrights metoo love redpilled mgtowforlife meninism boys positivity malepositivity
# 2260                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            inspiration innovation positivity management technology success
# 2261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          on the latest episode of the editing podcast denise and louise explain why they do not share content they dislike and why it is a good idea that you do not either if you see something that does not sit quite right with you do not spread it around  share something positive instead find out more about the hosts by visiting their websites  denise cowle httpslnkdingzuaewpa  louise harnby httpslnkdingvwmsuzediting podcast positivity theeditingpodcast
#
#            LABEL  TAGS
# 0        excited     1
# 1        excited     1
# 2        excited     1
# 3        excited     1
# 4        excited     1
# ...          ...   ...
# 2257  positivity     1
# 2258  positivity     1
# 2259  positivity     1
# 2260  positivity     1
# 2261  positivity     1
#
# [2255 rows x 4 columns]

# %%
unseen_complete_data['TAGS'].value_counts()
# Out:
# -1    1200
#  1    1055
# Name: TAGS, dtype: int64

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
#max_features = 2000
#tokenizer = Tokenizer(num_words = max_features, )
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(unseen_complete_data['POSTS'].values)
X = tokenizer.texts_to_sequences(unseen_complete_data['POSTS'].values)
X = pad_sequences(X, padding = 'post' , maxlen=100)
Y = pd.get_dummies(unseen_complete_data['TAGS']).values
#Y= complete_data['TAGS'].values

vocab_size = len(tokenizer.word_index)+1

# %%
embedding_matrix = np.zeros((vocab_size,300))
for word,i in tqdm(tokenizer.word_index.items()):
    embedding_value = model.get_word_vector(word)
    embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 92516/92516 [00:02<00:00, 44290.06it/s]

# %%
Y_test_new_unseen=[]
for val in Y:
  if val[0]==1:
    Y_test_new_unseen.append(0)
  else:
    Y_test_new_unseen.append(1)

# %%
from sklearn.metrics import classification_report

y_pred_unseen = lstm_model.predict(X, batch_size=10, verbose=1)
y_pred_bool_unseen = np.argmax(y_pred_unseen, axis=1)

print(classification_report(Y_test_new_unseen, y_pred_bool_unseen))
# Out:
# 226/226 [==============================] - 18s 78ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.89      0.85      1200
#            1       0.86      0.78      0.82      1055
#
#     accuracy                           0.84      2255
#    macro avg       0.84      0.83      0.83      2255
# weighted avg       0.84      0.84      0.84      2255

# %% [markdown]
# **Since false positives matter a lot, we focus on the precision values which are decent**

# %% [markdown]
# **Bidirectional LSTM using Glove embeddings**

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip -q glove.6B.zip
# Out:
# --2022-11-21 02:40:29--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2022-11-21 02:40:30--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2022-11-21 02:40:30--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  5.09MB/s    in 2m 39s
#
# 2022-11-21 02:43:10 (5.16 MB/s) - ‘glove.6B.zip’ saved [862182613/862182613]

# %%
# path_to_glove_file = os.path.join(
#     os.path.expanduser("~"), ".keras/datasets/glove.6B.100d.txt"
# )

# embeddings_index = {}
# with open("/content/glove.6B.300d.txt") as f:
#     for line in f:
#         word, coefs = line.split(maxsplit=1)
#         coefs = np.fromstring(coefs, "f", sep=" ")
#         embeddings_index[word] = coefs

# print("Found %s word vectors." % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
glove_embedding_matrix = np.zeros((vocab_size,300))
for word,i in tqdm(tokenizer.word_index.items()):
    embedding_value = embeddings_index.get(word)
    if embedding_value is not None:
        glove_embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 92516/92516 [00:00<00:00, 571634.31it/s]

# %%
glove_embedding_matrix.shape
# Out:
# (92517, 300)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras import utils
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization


from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Bidirectional, Dropout
embid_dim = 300
lstm_out = 128
lstm_model = keras.Sequential()
lstm_model.add(Embedding(vocab_size, embid_dim, weights = [glove_embedding_matrix] , trainable = False))
lstm_model.add(Bidirectional(LSTM(lstm_out, dropout=0.2)))
lstm_model.add(Dense(128, activation = 'relu'))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(64, activation = 'relu'))
lstm_model.add(Dense(2, activation = 'softmax'))  #if used pd.get dummies above
lstm_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, None, 300)         27755100
#
#  bidirectional_6 (Bidirectio  (None, 256)              439296
#  nal)
#
#  dense_18 (Dense)            (None, 128)               32896
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_19 (Dense)            (None, 64)                8256
#
#  dense_20 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 28,235,678
# Trainable params: 480,578
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=10,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)
batch_size = 200
lstm_model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
history = lstm_model.fit(X_train, Y_train, epochs = 50, batch_size=batch_size, verbose = 1, callbacks=[early_stopping_monitor], validation_data =(X_test, Y_test))
# Out:
# Epoch 1/50
# 74/74 [==============================] - 116s 1s/step - loss: 0.5156 - accuracy: 0.7388 - val_loss: 0.4496 - val_accuracy: 0.7914
# Epoch 2/50
# 74/74 [==============================] - 110s 1s/step - loss: 0.4028 - accuracy: 0.8175 - val_loss: 0.3612 - val_accuracy: 0.8374
# Epoch 3/50
# 74/74 [==============================] - 109s 1s/step - loss: 0.3577 - accuracy: 0.8351 - val_loss: 0.3405 - val_accuracy: 0.8434
# Epoch 4/50
# 74/74 [==============================] - 117s 2s/step - loss: 0.3473 - accuracy: 0.8403 - val_loss: 0.3467 - val_accuracy: 0.8511
# Epoch 5/50
# 74/74 [==============================] - 110s 1s/step - loss: 0.3258 - accuracy: 0.8474 - val_loss: 0.3072 - val_accuracy: 0.8585
# Epoch 6/50
# 74/74 [==============================] - 111s 1s/step - loss: 0.3092 - accuracy: 0.8558 - val_loss: 0.3291 - val_accuracy: 0.8517
# Epoch 7/50
# 74/74 [==============================] - 113s 2s/step - loss: 0.2963 - accuracy: 0.8626 - val_loss: 0.3008 - val_accuracy: 0.8532
# Epoch 8/50
# 74/74 [==============================] - 111s 1s/step - loss: 0.2735 - accuracy: 0.8741 - val_loss: 0.3094 - val_accuracy: 0.8597
# Epoch 9/50
# 74/74 [==============================] - 112s 2s/step - loss: 0.2657 - accuracy: 0.8761 - val_loss: 0.3031 - val_accuracy: 0.8646
# Epoch 10/50
# 74/74 [==============================] - 114s 2s/step - loss: 0.2524 - accuracy: 0.8864 - val_loss: 0.3096 - val_accuracy: 0.8663
# Epoch 11/50
# 74/74 [==============================] - 123s 2s/step - loss: 0.2401 - accuracy: 0.8885 - val_loss: 0.3156 - val_accuracy: 0.8526
# Epoch 12/50
# 74/74 [==============================] - ETA: 0s - loss: 0.2252 - accuracy: 0.8975
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-a878e3bcb1ef> in <module>
#      10 batch_size = 200
#      11 lstm_model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
# ---> 12 history = lstm_model.fit(X_train, Y_train, epochs = 50, batch_size=batch_size, verbose = 1, callbacks=[early_stopping_monitor], validation_data =(X_test, Y_test))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1454               use_multiprocessing=use_multiprocessing,
#    1455               return_dict=True,
# -> 1456               _use_cached_eval_dataset=True)
#    1457           val_logs = {'val_' + name: val for name, val in val_logs.items()}
#    1458           epoch_logs.update(val_logs)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    1754             with tf.profiler.experimental.Trace('test', step_num=step, _r=1):
#    1755               callbacks.on_test_batch_begin(step)
# -> 1756               tmp_logs = self.test_function(iterator)
#    1757               if data_handler.should_sync:
#    1758                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     952       # In this case we have not created variables on the first call. So we can
#     953       # run the first trace but we should fail if variables are created.
# --> 954       results = self._stateful_fn(*args, **kwds)
#     955       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2452        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2453     return graph_function._call_flat(
# -> 2454         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2455
#    2456   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1859       # No tape is watching; skip to running the function.
#    1860       return self._build_call_outputs(self._inference_function.call(
# -> 1861           ctx, args, cancellation_manager=cancellation_manager))
#    1862     forward_backward = self._select_forward_and_backward_functions(
#    1863         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     500               inputs=args,
#     501               attrs=attrs,
# --> 502               ctx=ctx)
#     503         else:
#     504           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
lstm_model.save('/content/gdrive/MyDrive/Colab Notebooks/Glove')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_19_layer_call_fn, lstm_cell_19_layer_call_and_return_conditional_losses, lstm_cell_20_layer_call_fn, lstm_cell_20_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %%
lstm_model = tf.keras.models.load_model('/content/gdrive/MyDrive/Colab Notebooks/Glove')

lstm_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, None, 300)         27755100
#
#  bidirectional_6 (Bidirectio  (None, 256)              439296
#  nal)
#
#  dense_18 (Dense)            (None, 128)               32896
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_19 (Dense)            (None, 64)                8256
#
#  dense_20 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 28,235,678
# Trainable params: 480,578
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
Y_test_new=[]
for val in Y_test:
  if val[0]==1:
    Y_test_new.append(0)
  else:
    Y_test_new.append(1)

# %%
from sklearn.metrics import classification_report

y_pred = lstm_model.predict(X_test, batch_size=64, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)

print(classification_report(Y_test_new, y_pred_bool))
# Out:
# 57/57 [==============================] - 15s 244ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.86      2114
#            1       0.80      0.82      0.81      1480
#
#     accuracy                           0.84      3594
#    macro avg       0.84      0.84      0.84      3594
# weighted avg       0.84      0.84      0.84      3594

# %% [markdown]
# **Testing GLOVE on unseen test data**

# %%
path = "/content/gdrive/MyDrive/Colab Notebooks/Unseen_test_data/"
dir_list = os.listdir(path)
pd.set_option('display.max_colwidth', None)

# %%
all_lines_list=list()
labels_list=list()
for filename in dir_list:
    file_extension_val=filename.split('.')
    file_extension=file_extension_val[1]
    if(file_extension=='txt'):
        label=filename.split('_')
        label=label[2]
        label=label.split('.')
        label=label[0]
        labels_list.append(label)
        # with open("/content/gdrive/MyDrive/Colab Notebooks/Unseen_test_data/"+filename, encoding='unicode_escape') as file_ptr:
        with open(path + "/" + filename, encoding='utf-8') as file_ptr:
            lines_temp = list()
            for line in file_ptr:
                if(line.strip()!="-----------------------------"):
                    lines_temp.append(line)
            all_lines_list.append(lines_temp)

# %%
df_posts=pd.DataFrame()
labels_global_list=list()
label_index=0
for lst in all_lines_list:
    df_temp = pd.DataFrame(lst)
    df_posts=df_posts.append(df_temp,ignore_index=True,)
#     label_length=len(lst)
    for i in range(len(lst)):
        labels_global_list.append(labels_list[label_index])
    label_index=label_index+1
    
df_labels = pd.DataFrame(labels_global_list)

# %%
unseen_complete_data = pd.concat([df_posts, df_labels], axis=1)
unseen_complete_data.columns = ['POSTS', 'LABEL']
unseen_complete_data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Does Excel run on Mac? You bet. So do Word, PowerPoint, and all the apps you need.\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                I'm about to start a new role at Capgemini and containing myself is a real issue.Don't ask 😌#excited\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               New chapter. #excited\n
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Flying away from the Nest and setting off for new adventures on the other side of the planet 🗺️This day marks a couple of important milestones:-         My first post ever on LinkedIn 🚀 (Is this really a milestone?)-         My last day working at Nestlé-         The beginning of a new and exciting journey 😍I am thrilled to announce that I’ll be moving to New Zealand as of February 2023 (#excited). Driven by the willingness to enrich ourselves as individuals, to go out of our comfort zone, to experience a new professional and personal environment, and to discover new outdoor experiences, my partner and I have decided to take that step. And why not?Since I graduated from ISIPCA in 2014, the past decade at Nestlé (wow, this sounds like a lot) which started with a 2-years internship has been incredibly rich and I feel very lucky for all the projects and experiences I went through. I met inspiring people and worked on innovative projects. From being part of the Nestlé R&D accelerator to the nesQino™️ journey, and plenty of other initiatives, I enjoyed the diversity of projects, activities, and challenges.The journey has also sometimes been punctuated with some doubts and questions, which were essential to go the extra mile. Those who know me know that I am always eager to learn new things. I don’t know yet what will come next, and I am very curious to see what the future will bring… The next two months will be busy organizing the move (and solving admin stuff), enjoying time with family and friends, recharging, and settling in New Zealand. I’ll be available for work as of February 2023 and I can’t wait to discover what New Zealand has to offer. I would love to start discussions about expatriation experiences, tips about New Zealand, potential work opportunities (including remote), …\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        #Excited about the great things to come from this partnership.  Gracias to my Omnicom Media Group familia (Geoffrey Calabrese, Kelly Metz, Amy Darwish) and TelevisaUnivision (Daniel Aversano, Richard Bertodatti) for making this happen! #multiculturalmarketing https://lnkd.in/eVpbW7CU\n
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# 2579                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Automate testing to catch bugs earlier in your development cycle.\n
# 2580  Is Twitter about to go bankrupt?https://lnkd.in/gnQtXcnC#layoff #layoffs #laidoff #job #today #linkedin #talent #searchforjobs #techlayoffs #techjobs #technews #careers #jobopening#W2 #contract #c2c #jobopportunities #career #recruiting #openforjobopportunities #Recession #Recession2022 #Recession2023 #jobsearch #ITRecruitment#java #phython #spring #springboot #microservices #hibernate #datajpa #kafka #aws #gcp #azure #javadeveloper #Akka #scala #benchsalesrecruiters#dotnetdeveloper #dotnet #devops #powerbi #uideveloper #networking #scrummaster #data #opportunity #opportunities #fullstackdeveloper #engineering #techcommunity #layoffsandjobreductions #hiring #team #development #grateful #comment #softwareengineering #frontend#dataanalysis #businessintelligence #processimprovement #industrialengineering #newopportunities #analyst #dataengineer #opentowork #openforwork #twitter #stripe #lyft #amazon #apple #microsoft #facebook #tesla #philips #zillow #convey #jpmc #salesforce #nytimes #nypost #wsj #layoff #layoffs #laidoff #job #today#javafullstackdeveloper #javajobs #hiringimmediately #hiring #hiringtalent #marketing #project # #project #Snap #softwareengineer #work#leadership #digitalhealth #medicaldevice #biotechnology #projectAdditionally #career #opportunities #activelylooking #talent #businessintelligenceanalyst #international #students #CPT #OPT #EAD #OPTEAD #Fulltime #H1B #H4EAD #TN #TNVISA #tnjobs #H1BVISA #Citizens #GC #GCEAD #uscitizens #usajobs #usc #usajob #usa2022 #usa #usa2023 #usaitjobs #uscontractjobs #usjobseeker #usjob#dataanalyst #businessanalyst #businessanalysis #analytics #workplace #outsourcedhr #payroll #onboarding#pgmp #productdevelopment #programmanagement #productmanagement #ProjectManagement #productmanager #programmanager #culture #remotework#jobalert #canadajobs #fulltimeposition #candidatesearch #fulltimejobs #jobfair #jobdescription #jobavailable #jobchangers #canada #canadaworkvisa #fulltime #copr #canadastaffing #canadarecruitment #canadacareers #canadajobseeker #canadaitjob #torontocanada #canadaitjobs #jobhiring #jobforyou #jobalerts #canadaprvisa #canadajobseekers#permanentjobs #permanentjob #permanentrecruitment #permanentrole #opentonewopportunities #torontoitjobs #jobseekers #Recruiting#Jobposting #LinkedIn #Openings #Jobvacancy #Jobalert #Jobhunters #activelyhiring #BulkCanadaJobs #informaticajobs #informatica #bigdata #hadoop#tech #help #economy #jobhunt #network#nyc #denver #colorado #losangeles #boston #tampa #florida #michiganjobs #oregoan #sandiego #houston #dallas #itjobs #washington #dallas#chicago #chicagojobs #dfw #plano #dallas #dallasjobs #austin #austinjobs #Cali #CaliJobs #California #Houston #HoustonJobs #atlanta #atlantajobs#nyc #newyork #nycjobs #newyorkjobs #detroit #michigan #mexico #mexicojobs #siliconvalley\n
# 2581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             That moment when the cast of #JurassicWorldDominion surprised 350 students with free laptops.Just one of many surprises for these amazing students during an all-expense-paid trip to Universal Studios to launch our Jurassic World-themed STEAM initiative. Learn more about this cross-company program with Universal Pictures, Universal Parks & Resorts, and the Council for Opportunity in Education to help ensure more young people have access to the resources and opportunities they need to succeed in today’s digital world. #ProjectUP\n
# 2582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Develop crucial skills and knowledge in Brown’s Online MPH to address the many health challenges affecting the world today.\n
# 2583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Propel your future forward by taking courses online to earn a graduate certificate or master's degree from Stanford University. Learn more!\n
#
#               LABEL
# 0           excited
# 1           excited
# 2           excited
# 3           excited
# 4           excited
# ...             ...
# 2579  recession2022
# 2580  recession2022
# 2581  recession2022
# 2582  recession2022
# 2583  recession2022
#
# [2584 rows x 2 columns]

# %%
#convert to lowercase
unseen_complete_data['POSTS']=unseen_complete_data['POSTS'].str.lower()

# %%
#remove html content
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].apply(lambda x: re.split('<[^<>]*>', str(x))[0])

# %%
def contr(post_text):
     posts_body_list=[]
     for r in post_text:
         decontract_posts_body = contractions.fix(r)
         r = ''.join(decontract_posts_body)
         r = re.sub("\s\s+", " ", r) # remove extra spaces
         posts_body_list.append(r)
     return posts_body_list

# %%
unseen_complete_data['POSTS']=contr(unseen_complete_data['POSTS'].values)

# %%
#remove non-alphabetical values
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].replace('[^a-zA-Z ]', '', regex=True)

# %%
import numpy as np
unseen_complete_data['TAGS']=np.where( (unseen_complete_data['LABEL']=='excited') | (unseen_complete_data['LABEL']=='hiring') | (unseen_complete_data['LABEL']=='positivity') | (unseen_complete_data['LABEL']=='positivevibes') | (unseen_complete_data['LABEL']=='grateful') | (unseen_complete_data['LABEL']=='newjob') | (unseen_complete_data['LABEL']=='blessed') | (unseen_complete_data['LABEL']=='happy') | (unseen_complete_data['LABEL']=='lmao') | (unseen_complete_data['LABEL']=='funny') | (unseen_complete_data['LABEL']=='fun') | (unseen_complete_data['LABEL']=='lol') , 1, -1)

# %%
unseen_complete_data=unseen_complete_data.drop_duplicates(keep='last').reset_index()

# %%
unseen_complete_data['POSTS'].replace('', np.nan, inplace=True)
unseen_complete_data.dropna(subset=['POSTS'], inplace=True)
unseen_complete_data
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 2257   2579
# 2258   2580
# 2259   2581
# 2260   2582
# 2261   2583
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              does excel run on mac you bet so do word powerpoint and all the apps you need
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        i am about to start a new role at capgemini and containing myself is a real issuedo not ask excited
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        new chapter excited
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  flying away from the nest and setting off for new adventures on the other side of the planet this day marks a couple of important milestones my first post ever on linkedin  is this really a milestone my last day working at nestl the beginning of a new and exciting journey i am thrilled to announce that i will be moving to new zealand as of february  excited driven by the willingness to enrich ourselves as individuals to go out of our comfort zone to experience a new professional and personal environment and to discover new outdoor experiences my partner and i have decided to take that step and why notsince i graduated from isipca in  the past decade at nestl wow this sounds like a lot which started with a years internship has been incredibly rich and i feel very lucky for all the projects and experiences i went through i met inspiring people and worked on innovative projects from being part of the nestl rd accelerator to the nesqino journey and plenty of other initiatives i enjoyed the diversity of projects activities and challengesthe journey has also sometimes been punctuated with some doubts and questions which were essential to go the extra mile those who know me know that i am always eager to learn new things i do not know yet what will come next and i am very curious to see what the future will bring the next two months will be busy organizing the move and solving admin stuff enjoying time with family and friends recharging and settling in new zealand i will be available for work as of february  and i cannot wait to discover what new zealand has to offer i would love to start discussions about expatriation experiences tips about new zealand potential work opportunities including remote
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 excited about the great things to come from this partnership gracias to my omnicom media group familia geoffrey calabrese kelly metz amy darwish and televisaunivision daniel aversano richard bertodatti for making this happen multiculturalmarketing httpslnkdinevpbwcu
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 2257                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        automate testing to catch bugs earlier in your development cycle
# 2258  is twitter about to go bankrupthttpslnkdingnqtxcnclayoff layoffslaidoff job today linkedin talent searchforjobs techlayoffs techjobs technews careers jobopeningw contract cc jobopportunities career recruiting openforjobopportunities recession recession recession jobsearch itrecruitmentjava phython spring springboot microservices hibernate datajpa kafka aws gcp azure javadeveloper akka scala benchsalesrecruitersdotnetdeveloper dotnet devops powerbi uideveloper networking scrummaster data opportunity opportunities fullstackdeveloper engineering techcommunity layoffsandjobreductions hiring team development grateful comment softwareengineering frontenddataanalysis businessintelligence processimprovementindustrialengineering newopportunities analyst dataengineer opentowork openforwork twitter stripe lyft amazon apple microsoft facebook tesla philips zillow convey jpmc salesforce nytimes nypost wsj layoff layoffslaidoff job todayjavafullstackdeveloper javajobs hiringimmediately hiring hiringtalent marketing project  project snap softwareengineer workleadership digitalhealth medicaldevice biotechnology projectadditionally career opportunities activelylooking talent businessintelligenceanalystinternational students cpt opt ead optead fulltimehb head tn tnvisa tnjobs hbvisa citizens gc gcead uscitizens usajobs usc usajob usa usa usa usaitjobs uscontractjobs usjobseeker usjobdataanalyst businessanalystbusinessanalysis analytics workplace outsourcedhr payroll onboardingpgmp productdevelopment programmanagement productmanagement projectmanagement productmanager programmanager culture remoteworkjobalert canadajobs fulltimeposition candidatesearch fulltimejobs jobfair jobdescription jobavailable jobchangers canada canadaworkvisa fulltime copr canadastaffing canadarecruitment canadacareers canadajobseeker canadaitjob torontocanada canadaitjobsjobhiring jobforyou jobalerts canadaprvisa canadajobseekerspermanentjobs permanentjob permanentrecruitment permanentrole opentonewopportunities torontoitjobs jobseekers recruitingjobposting linkedin openings jobvacancy jobalert jobhunters activelyhiring bulkcanadajobs informaticajobs informatica bigdata hadooptech help economy jobhunt networknyc denver colorado losangeles boston tampa florida michiganjobs oregoan sandiego houston dallas itjobs washington dallaschicago chicagojobs dfw plano dallas dallasjobs austin austinjobs cali calijobs california houston houstonjobs atlanta atlantajobsnyc newyork nycjobs newyorkjobs detroit michiganmexico mexicojobs siliconvalley
# 2259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    that moment when the cast of jurassicworlddominion surprised  students with free laptopsjust one of many surprises for these amazing students during an allexpensepaid trip to universal studios to launch our jurassic worldthemed steam initiative learn more about this crosscompany program with universal pictures universal parks  resorts and the council for opportunity in education to help ensure more young people have access to the resources and opportunities they need to succeed in todays digital world projectup
# 2260                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               develop crucial skills and knowledge in browns online mph to address the many health challenges affecting the world today
# 2261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                propel your future forward by taking courses online to earn a graduate certificate or masters degree from stanford university learn more
#
#               LABEL  TAGS
# 0           excited     1
# 1           excited     1
# 2           excited     1
# 3           excited     1
# 4           excited     1
# ...             ...   ...
# 2257  recession2022    -1
# 2258  recession2022    -1
# 2259  recession2022    -1
# 2260  recession2022    -1
# 2261  recession2022    -1
#
# [2255 rows x 4 columns]

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
#max_features = 2000
#tokenizer = Tokenizer(num_words = max_features, )
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(unseen_complete_data['POSTS'].values)
X = tokenizer.texts_to_sequences(unseen_complete_data['POSTS'].values)
X = pad_sequences(X, padding = 'post' , maxlen=100)
Y = pd.get_dummies(unseen_complete_data['TAGS']).values
#Y= complete_data['TAGS'].values

vocab_size = len(tokenizer.word_index)+1

# %%
embedding_matrix = np.zeros((vocab_size,300))
for word,i in tqdm(tokenizer.word_index.items()):
    embedding_value = model.get_word_vector(word)
    embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 92516/92516 [00:03<00:00, 24636.59it/s]

# %%
Y_test_new_unseen=[]
for val in Y:
  if val[0]==1:
    Y_test_new_unseen.append(0)
  else:
    Y_test_new_unseen.append(1)

# %%
from sklearn.metrics import classification_report

y_pred_unseen = lstm_model.predict(X, batch_size=10, verbose=1)
y_pred_bool_unseen = np.argmax(y_pred_unseen, axis=1)

print(classification_report(Y_test_new_unseen, y_pred_bool_unseen))
# Out:
# 226/226 [==============================] - 15s 66ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86      1200
#            1       0.85      0.83      0.84      1055
#
#     accuracy                           0.85      2255
#    macro avg       0.85      0.85      0.85      2255
# weighted avg       0.85      0.85      0.85      2255

# %% [markdown]
# **Google pre-trained w2v**

# %%
from gensim.models import KeyedVectors
from tqdm import tqdm

# %%
# Load back with memory-mapping = read-only, shared across processes.
wv = KeyedVectors.load("/content/gdrive/MyDrive/group_17/w2v_300.wordvectors", mmap='r')

# %%
# create an word2vec_dict for words as key and corresponding 300 dim vector as value
word2vec_dict = {}
for word in tqdm(wv.vocab):
    word2vec_dict[word] = wv[word]
print("Found %s word vectors." % len(word2vec_dict))
# Out:
# 100%|██████████| 3000000/3000000 [00:19<00:00, 154740.63it/s]
# Found 3000000 word vectors.

# %%
w2v_embedding_matrix = np.zeros((vocab_size,300))
for word,i in tqdm(tokenizer.word_index.items()):
    embedding_value = word2vec_dict.get(word)
    if embedding_value is not None:
        w2v_embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 92516/92516 [01:28<00:00, 1043.57it/s]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import preprocessing
from tensorflow.keras import utils
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization


from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Bidirectional, Dropout
embid_dim = 300
lstm_out = 128
lstm_model = keras.Sequential()
lstm_model.add(Embedding(vocab_size, embid_dim, weights = [w2v_embedding_matrix] , trainable = False))
lstm_model.add(Bidirectional(LSTM(lstm_out, dropout=0.2)))
lstm_model.add(Dense(128, activation = 'relu'))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(64, activation = 'relu'))
lstm_model.add(Dense(2, activation = 'softmax'))  #if used pd.get dummies above
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 300)         27755100
#
#  bidirectional (Bidirectiona  (None, 256)              439296
#  l)
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,235,678
# Trainable params: 480,578
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=10,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)
batch_size = 200
lstm_model.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
history = lstm_model.fit(X_train, Y_train, epochs = 50, batch_size=batch_size, verbose = 1, callbacks=[early_stopping_monitor], validation_data =(X_test, Y_test))
# Out:
# Epoch 1/50
# 54/54 [==============================] - 72s 1s/step - loss: 0.5549 - accuracy: 0.7058 - val_loss: 0.4414 - val_accuracy: 0.7863
# Epoch 2/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.4092 - accuracy: 0.8095 - val_loss: 0.3724 - val_accuracy: 0.8283
# Epoch 3/50
# 54/54 [==============================] - 61s 1s/step - loss: 0.3532 - accuracy: 0.8316 - val_loss: 0.3325 - val_accuracy: 0.8378
# Epoch 4/50
# 54/54 [==============================] - 79s 1s/step - loss: 0.3213 - accuracy: 0.8498 - val_loss: 0.3114 - val_accuracy: 0.8514
# Epoch 5/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.3032 - accuracy: 0.8583 - val_loss: 0.3226 - val_accuracy: 0.8509
# Epoch 6/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.3099 - accuracy: 0.8579 - val_loss: 0.3301 - val_accuracy: 0.8439
# Epoch 7/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.2834 - accuracy: 0.8674 - val_loss: 0.3083 - val_accuracy: 0.8553
# Epoch 8/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.2629 - accuracy: 0.8767 - val_loss: 0.3018 - val_accuracy: 0.8648
# Epoch 9/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.2460 - accuracy: 0.8864 - val_loss: 0.3083 - val_accuracy: 0.8578
# Epoch 10/50
# 54/54 [==============================] - 55s 1s/step - loss: 0.2302 - accuracy: 0.8955 - val_loss: 0.3052 - val_accuracy: 0.8653
# Epoch 11/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.2202 - accuracy: 0.8963 - val_loss: 0.3183 - val_accuracy: 0.8637
# Epoch 12/50
# 54/54 [==============================] - 54s 1s/step - loss: 0.2075 - accuracy: 0.9098 - val_loss: 0.3300 - val_accuracy: 0.8648
# Epoch 13/50
# 54/54 [==============================] - 59s 1s/step - loss: 0.1920 - accuracy: 0.9124 - val_loss: 0.3117 - val_accuracy: 0.8642
# Epoch 14/50
# 54/54 [==============================] - 54s 1s/step - loss: 0.1849 - accuracy: 0.9149 - val_loss: 0.3234 - val_accuracy: 0.8653
# Epoch 15/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.1809 - accuracy: 0.9188 - val_loss: 0.3086 - val_accuracy: 0.8645
# Epoch 16/50
# 54/54 [==============================] - 55s 1s/step - loss: 0.1668 - accuracy: 0.9246 - val_loss: 0.3588 - val_accuracy: 0.8678
# Epoch 17/50
# 54/54 [==============================] - 56s 1s/step - loss: 0.1609 - accuracy: 0.9263 - val_loss: 0.3541 - val_accuracy: 0.8625
# Epoch 18/50
# 54/54 [==============================] - 54s 1s/step - loss: 0.1470 - accuracy: 0.9340 - val_loss: 0.3869 - val_accuracy: 0.8620

# %%
lstm_model.save('/content/gdrive/MyDrive/group_17/bi_lstm_w2v')
lstm_model.save_weights(filepath='/content/gdrive/MyDrive/group_17/bi_lstm_w2v.h5')
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %%
lstm_model = tf.keras.models.load_model('/content/gdrive/MyDrive/group_17/bi_lstm_w2v')

lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 300)         27755100
#
#  bidirectional (Bidirectiona  (None, 256)              439296
#  l)
#
#  dense (Dense)               (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,235,678
# Trainable params: 480,578
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
Y_test_new=[]
for val in Y_test:
  if val[0]==1:
    Y_test_new.append(0)
  else:
    Y_test_new.append(1)

# %%
from sklearn.metrics import classification_report

y_pred = lstm_model.predict(X_test, batch_size=64, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)

print(classification_report(Y_test_new, y_pred_bool))
# Out:
# 57/57 [==============================] - 9s 148ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89      2098
#            1       0.88      0.79      0.83      1496
#
#     accuracy                           0.86      3594
#    macro avg       0.87      0.85      0.86      3594
# weighted avg       0.87      0.86      0.86      3594

# %% [markdown]
# **Testing the model on completely new/unseen data**

# %%
path = "/content/gdrive/MyDrive/group_17/unseen_test_data"
dir_list = os.listdir(path)
pd.set_option('display.max_colwidth', None)

# %%
all_lines_list=list()
labels_list=list()
for filename in dir_list:
    file_extension_val=filename.split('.')
    file_extension=file_extension_val[1]
    if(file_extension=='txt'):
        label=filename.split('_')
        label=label[2]
        label=label.split('.')
        label=label[0]
        labels_list.append(label)
        # with open("/content/gdrive/MyDrive/Colab Notebooks/Unseen_test_data/"+filename, encoding='unicode_escape') as file_ptr:
        with open(path + "/" + filename, encoding='utf-8') as file_ptr:
            lines_temp = list()
            for line in file_ptr:
                if(line.strip()!="-----------------------------"):
                    lines_temp.append(line)
            all_lines_list.append(lines_temp)

# %%
df_posts=pd.DataFrame()
labels_global_list=list()
label_index=0
for lst in all_lines_list:
    df_temp = pd.DataFrame(lst)
    df_posts=df_posts.append(df_temp,ignore_index=True,)
#     label_length=len(lst)
    for i in range(len(lst)):
        labels_global_list.append(labels_list[label_index])
    label_index=label_index+1
    
df_labels = pd.DataFrame(labels_global_list)

# %%
unseen_complete_data = pd.concat([df_posts, df_labels], axis=1)
unseen_complete_data.columns = ['POSTS', 'LABEL']
unseen_complete_data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Does Excel run on Mac? You bet. So do Word, PowerPoint, and all the apps you need.\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I'm about to start a new role at Capgemini and containing myself is a real issue.Don't ask 😌#excited\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 New chapter. #excited\n
# 3     Flying away from the Nest and setting off for new adventures on the other side of the planet 🗺️This day marks a couple of important milestones:-         My first post ever on LinkedIn 🚀 (Is this really a milestone?)-         My last day working at Nestlé-         The beginning of a new and exciting journey 😍I am thrilled to announce that I’ll be moving to New Zealand as of February 2023 (#excited). Driven by the willingness to enrich ourselves as individuals, to go out of our comfort zone, to experience a new professional and personal environment, and to discover new outdoor experiences, my partner and I have decided to take that step. And why not?Since I graduated from ISIPCA in 2014, the past decade at Nestlé (wow, this sounds like a lot) which started with a 2-years internship has been incredibly rich and I feel very lucky for all the projects and experiences I went through. I met inspiring people and worked on innovative projects. From being part of the Nestlé R&D accelerator to the nesQino™️ journey, and plenty of other initiatives, I enjoyed the diversity of projects, activities, and challenges.The journey has also sometimes been punctuated with some doubts and questions, which were essential to go the extra mile. Those who know me know that I am always eager to learn new things. I don’t know yet what will come next, and I am very curious to see what the future will bring… The next two months will be busy organizing the move (and solving admin stuff), enjoying time with family and friends, recharging, and settling in New Zealand. I’ll be available for work as of February 2023 and I can’t wait to discover what New Zealand has to offer. I would love to start discussions about expatriation experiences, tips about New Zealand, potential work opportunities (including remote), …\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          #Excited about the great things to come from this partnership.  Gracias to my Omnicom Media Group familia (Geoffrey Calabrese, Kelly Metz, Amy Darwish) and TelevisaUnivision (Daniel Aversano, Richard Bertodatti) for making this happen! #multiculturalmarketing https://lnkd.in/eVpbW7CU\n
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2579                                                                                                                                                                                                                                                                                                                                                                                                                  Allowing Ourselves To Be Nurtured Let yourself be nurtured and loved.Let people be there for you.Allow yourself to be held when it would feel good.Let someone listen to you, support and encourage you when you need that.Receive comfort from someone's physical presence when you need that. Allow yourself to be supported emotionally and cared about.For too long, we've stood in the background, attending to the needs of others and claiming we have no needs of our own.We've shut off, for too long, the part of us that longs to be nurtured.It is time, now, to claim those needs, identify them, and understand that we deserve to have them met. What are our needs? What would feel good? What kinds of ways would we like others to nurture and support us?The clearer we can be about our needs, the greater the possibility they will be met.Hugs. A listening ear. Support. Encouragement.The physical and emotional presence of people who care about us.Doesn't that sound good? Tempting?No matter how old or successful we are,  we never outgrow our need for nurturing and love.Enjoyed reading this? Follow me on: https://bit.ly/3AqIY6k #couplegoals #love #loved #lovedogs #loveforever #loveislove #lovelive #lovely #lovemakeup #lovemylife #lovenature #lovequotes #lovers #loves #lovestory #lovethem #loveu #lovewhatyoudo #loveyou #loveyourbody #meditation #mindset #momlife #mylove #poetry #positivity #relationshipgoals\n
# 2580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Good morning 😊#goodmorning #goodlife #dontgiveup #win #motivational #motivationalquotes #motivationalspeaker #goodvibesonly #vibes #energy #positivemindset #positivity #sucessmindset #sucess #sucessful #quoteoftheday #quotesaboutlife #opportunites #opportunityseeker #growthopportunities #growth #goals #winner\n
# 2581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Shout out to all the men of REALSTA who despite all odds and obstacles paved the way for themselves in this over-ambitious world. May you get more strength and love. You are doing the best you can and we are all proud of you. Wishing you a very Happy International Men's Day!#internationalmensday #mensday #men #mensrights #meninist #mentoo #mgtow #mra #antifeminist #equality #antifeminism #feminism #redpill #mensmentalhealth #himtoo #mgtowisthefuture #november #equalrights #metoo #love #redpilled #mgtowforlife #meninism #boys #positivity #malepositivity\n
# 2582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              #inspiration #innovation #positivity #management #technology #success\n
# 2583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            On the latest episode of The Editing Podcast, Denise and Louise explain why they don’t share content they dislike and why it’s a good idea that you don’t, either. If you see something that doesn’t sit quite right with you, don’t spread it around — share something positive instead. 🌻Find out more about the hosts by visiting their websites. – Denise Cowle: https://lnkd.in/gzuAEwPA – Louise Harnby: https://lnkd.in/gV7wMsuZ#editing #podcast #positivity #theeditingpodcast\n
#
#            LABEL
# 0        excited
# 1        excited
# 2        excited
# 3        excited
# 4        excited
# ...          ...
# 2579  positivity
# 2580  positivity
# 2581  positivity
# 2582  positivity
# 2583  positivity
#
# [2584 rows x 2 columns]

# %%
#convert to lowercase
unseen_complete_data['POSTS']=unseen_complete_data['POSTS'].str.lower()

# %%
#remove html content
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].apply(lambda x: re.split('<[^<>]*>', str(x))[0])

# %%
def contr(post_text):
     posts_body_list=[]
     for r in post_text:
         decontract_posts_body = contractions.fix(r)
         r = ''.join(decontract_posts_body)
         r = re.sub("\s\s+", " ", r) # remove extra spaces
         posts_body_list.append(r)
     return posts_body_list

# %%
unseen_complete_data['POSTS']=contr(unseen_complete_data['POSTS'].values)

# %%
#remove non-alphabetical values
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].replace('[^a-zA-Z ]', '', regex=True)

# %%
import numpy as np
unseen_complete_data['TAGS']=np.where( (unseen_complete_data['LABEL']=='excited') | (unseen_complete_data['LABEL']=='hiring') | (unseen_complete_data['LABEL']=='positivity') | (unseen_complete_data['LABEL']=='positivevibes') | (unseen_complete_data['LABEL']=='grateful') | (unseen_complete_data['LABEL']=='newjob') | (unseen_complete_data['LABEL']=='blessed') | (unseen_complete_data['LABEL']=='happy') | (unseen_complete_data['LABEL']=='lmao') | (unseen_complete_data['LABEL']=='funny') | (unseen_complete_data['LABEL']=='fun') | (unseen_complete_data['LABEL']=='lol') , 1, -1)

# %%
unseen_complete_data=unseen_complete_data.drop_duplicates(keep='last').reset_index()

# %%
unseen_complete_data['POSTS'].replace('', np.nan, inplace=True)
unseen_complete_data.dropna(subset=['POSTS'], inplace=True)
unseen_complete_data
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 2257   2579
# 2258   2580
# 2259   2581
# 2260   2582
# 2261   2583
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 does excel run on mac you bet so do word powerpoint and all the apps you need
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i am about to start a new role at capgemini and containing myself is a real issuedo not ask excited
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           new chapter excited
# 3     flying away from the nest and setting off for new adventures on the other side of the planet this day marks a couple of important milestones my first post ever on linkedin  is this really a milestone my last day working at nestl the beginning of a new and exciting journey i am thrilled to announce that i will be moving to new zealand as of february  excited driven by the willingness to enrich ourselves as individuals to go out of our comfort zone to experience a new professional and personal environment and to discover new outdoor experiences my partner and i have decided to take that step and why notsince i graduated from isipca in  the past decade at nestl wow this sounds like a lot which started with a years internship has been incredibly rich and i feel very lucky for all the projects and experiences i went through i met inspiring people and worked on innovative projects from being part of the nestl rd accelerator to the nesqino journey and plenty of other initiatives i enjoyed the diversity of projects activities and challengesthe journey has also sometimes been punctuated with some doubts and questions which were essential to go the extra mile those who know me know that i am always eager to learn new things i do not know yet what will come next and i am very curious to see what the future will bring the next two months will be busy organizing the move and solving admin stuff enjoying time with family and friends recharging and settling in new zealand i will be available for work as of february  and i cannot wait to discover what new zealand has to offer i would love to start discussions about expatriation experiences tips about new zealand potential work opportunities including remote
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    excited about the great things to come from this partnership gracias to my omnicom media group familia geoffrey calabrese kelly metz amy darwish and televisaunivision daniel aversano richard bertodatti for making this happen multiculturalmarketing httpslnkdinevpbwcu
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 2257                                                                                                                                                                                                                                                                                                                                                                                           allowing ourselves to be nurturedlet yourself be nurtured and lovedlet people be there for youallow yourself to be held when it would feel goodlet someone listen to you support and encourage you when you need thatreceive comfort from someone is physical presence when you need that allow yourself to be supported emotionally and cared aboutfor too long we have stood in the background attending to the needs of others and claiming we have no needs of our ownwe have shut off for too long the part of us that longs to be nurturedit is time now to claim those needs identify them and understand that we deserve to have them metwhat are our needs what would feel good what kinds of ways would we like others to nurture and support usthe clearer we can be about our needs the greater the possibility they will be methugs a listening ear support encouragementthe physical and emotional presence of people who care about usdoes not that sound good temptingno matter how old or successful we are we never outgrow our need for nurturing and loveenjoyed reading this follow me on httpsbitlyaqiyk couplegoals love loved lovedogs loveforever loveislove lovelive lovely lovemakeup lovemylife lovenature lovequotes lovers loves lovestory lovethem loveu lovewhatyoudo loveyou loveyourbody meditation mindset momlife mylove poetry positivity relationshipgoals
# 2258                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning goodmorning goodlife dontgiveup win motivational motivationalquotes motivationalspeaker goodvibesonly vibes energy positivemindset positivity sucessmindset sucess sucessful quoteoftheday quotesaboutlife opportunites opportunityseeker growthopportunities growth goals winner
# 2259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                shout out to all the men of realsta who despite all odds and obstacles paved the way for themselves in this overambitious worldmay you get more strength and love you are doing the best you can and we are all proud of youwishing you a very happy international mens dayinternationalmensday mensday men mensrights meninist mentoo mgtow mra antifeminist equality antifeminism feminism redpill mensmentalhealthhimtoo mgtowisthefuture november equalrights metoo love redpilled mgtowforlife meninism boys positivity malepositivity
# 2260                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            inspiration innovation positivity management technology success
# 2261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          on the latest episode of the editing podcast denise and louise explain why they do not share content they dislike and why it is a good idea that you do not either if you see something that does not sit quite right with you do not spread it around  share something positive instead find out more about the hosts by visiting their websites  denise cowle httpslnkdingzuaewpa  louise harnby httpslnkdingvwmsuzediting podcast positivity theeditingpodcast
#
#            LABEL  TAGS
# 0        excited     1
# 1        excited     1
# 2        excited     1
# 3        excited     1
# 4        excited     1
# ...          ...   ...
# 2257  positivity     1
# 2258  positivity     1
# 2259  positivity     1
# 2260  positivity     1
# 2261  positivity     1
#
# [2255 rows x 4 columns]

# %%
unseen_complete_data['TAGS'].value_counts()
# Out:
# -1    1200
#  1    1055
# Name: TAGS, dtype: int64

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
#max_features = 2000
#tokenizer = Tokenizer(num_words = max_features, )
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(unseen_complete_data['POSTS'].values)
X = tokenizer.texts_to_sequences(unseen_complete_data['POSTS'].values)
X = pad_sequences(X, padding = 'post' , maxlen=100)
Y = pd.get_dummies(unseen_complete_data['TAGS']).values
#Y= complete_data['TAGS'].values

vocab_size = len(tokenizer.word_index)+1

# %%
# w2v test
te_w2v_embedding_matrix = np.zeros((vocab_size,300))
for word,i in tqdm(tokenizer.word_index.items()):
    embedding_value = word2vec_dict.get(word)
    te_w2v_embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 92516/92516 [00:00<00:00, 209601.02it/s]

# %%
Y_test_new_unseen=[]
for val in Y:
  if val[0]==1:
    Y_test_new_unseen.append(0)
  else:
    Y_test_new_unseen.append(1)

# %%
from sklearn.metrics import classification_report

y_pred_unseen = lstm_model.predict(X, batch_size=10, verbose=1)
y_pred_bool_unseen = np.argmax(y_pred_unseen, axis=1)

print(classification_report(Y_test_new_unseen, y_pred_bool_unseen))
# Out:
# 226/226 [==============================] - 11s 47ms/step
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      1200
#            1       0.91      0.77      0.83      1055
#
#     accuracy                           0.85      2255
#    macro avg       0.86      0.85      0.85      2255
# weighted avg       0.86      0.85      0.85      2255

# %% [markdown]
# **BERT**

# %%
# !pip install bert-for-tf2
# !pip install bert-tensorflow
# !pip install --upgrade bert
# !pip install tokenization
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert-for-tf2
#   Downloading bert-for-tf2-0.14.9.tar.gz (41 kB)
#      |████████████████████████████████| 41 kB 168 kB/s
# Collecting py-params>=0.9.6
#   Downloading py-params-0.10.2.tar.gz (7.4 kB)
# Collecting params-flow>=0.8.0
#   Downloading params-flow-0.8.2.tar.gz (22 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from params-flow>=0.8.0->bert-for-tf2) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from params-flow>=0.8.0->bert-for-tf2) (4.64.1)
# Building wheels for collected packages: bert-for-tf2, params-flow, py-params
#   Building wheel for bert-for-tf2 (setup.py) ... done
#   Created wheel for bert-for-tf2: filename=bert_for_tf2-0.14.9-py3-none-any.whl size=30534 sha256=8e7cb20da8c6c5e63422ef3e83dda3177f2034c5ae134a31d7f33072b9f24133
#   Stored in directory: /root/.cache/pip/wheels/47/b6/e5/8c76ec779f54bc5c2f1b57d2200bb9c77616da83873e8acb53
#   Building wheel for params-flow (setup.py) ... done
#   Created wheel for params-flow: filename=params_flow-0.8.2-py3-none-any.whl size=19472 sha256=bde71ab2dfe1d7e5ae5d39b18fef4fa490758be565b13931ebe02e3c69ff7c32
#   Stored in directory: /root/.cache/pip/wheels/0e/fc/d2/a44fff33af0f233d7def6e7de413006d57c10e10ad736fe8f5
#   Building wheel for py-params (setup.py) ... done
#   Created wheel for py-params: filename=py_params-0.10.2-py3-none-any.whl size=7911 sha256=c66fa6dbc4f0b1f46a8d4fd5bb2a1c3fdaab0dfce1794e686df0ad1656a66c0c
#   Stored in directory: /root/.cache/pip/wheels/e1/11/67/33cc51bbee127cb8fb2ba549cd29109b2f22da43ddf9969716
# Successfully built bert-for-tf2 params-flow py-params
# Installing collected packages: py-params, params-flow, bert-for-tf2
# Successfully installed bert-for-tf2-0.14.9 params-flow-0.8.2 py-params-0.10.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert-tensorflow
#   Downloading bert_tensorflow-1.0.4-py2.py3-none-any.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.0 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from bert-tensorflow) (1.15.0)
# Installing collected packages: bert-tensorflow
# Successfully installed bert-tensorflow-1.0.4
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert
#   Downloading bert-2.2.0.tar.gz (3.5 kB)
# Collecting erlastic
#   Downloading erlastic-2.0.0.tar.gz (6.8 kB)
# Building wheels for collected packages: bert, erlastic
#   Building wheel for bert (setup.py) ... done
#   Created wheel for bert: filename=bert-2.2.0-py3-none-any.whl size=3764 sha256=18a11b562dc61ef93d0670a76d97798d0f88d84e1ff1bf5fb1f6d996baa5b80a
#   Stored in directory: /root/.cache/pip/wheels/bb/31/1b/c05f362e347429b7436954d1a2280fe464731e8f569123a848
#   Building wheel for erlastic (setup.py) ... done
#   Created wheel for erlastic: filename=erlastic-2.0.0-py3-none-any.whl size=6795 sha256=fae9ba69be402e7e234305aad5c59cf30d4f1c63225755bba1e171ce5e61c076
#   Stored in directory: /root/.cache/pip/wheels/94/f1/b4/0b98b1e94775da6a0b1130e342d22af05cd269e1172c19f40f
# Successfully built bert erlastic
# Installing collected packages: erlastic, bert
# Successfully installed bert-2.2.0 erlastic-2.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tokenization
#   Downloading tokenization-1.0.7-py3-none-any.whl (10 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from tokenization) (2022.6.2)
# Installing collected packages: tokenization
# Successfully installed tokenization-1.0.7

# %%
from bert import tokenization
from bert.tokenization.bert_tokenization import FullTokenizer
import tensorflow as tf
import tensorflow_hub as hub
import logging
logging.basicConfig(level=logging.INFO)

# %%
import tensorflow_hub as hub
module_url = 'https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/2'
bert_layer = hub.KerasLayer(module_url, trainable=True)

# %%
vocab_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
do_lower_case = bert_layer.resolved_object.do_lower_case.numpy()
tokenizer = FullTokenizer(vocab_file, do_lower_case)

def bert_encode(texts, tokenizer, max_len=512):
    all_tokens = []
    all_masks = []
    all_segments = []
    
    for text in texts:
        text = tokenizer.tokenize(text)
            
        text = text[:max_len-2]
        input_sequence = ["[CLS]"] + text + ["[SEP]"]
        pad_len = max_len - len(input_sequence)
        
        tokens = tokenizer.convert_tokens_to_ids(input_sequence) + [0] * pad_len
        pad_masks = [1] * len(input_sequence) + [0] * pad_len
        segment_ids = [0] * max_len
        
        all_tokens.append(tokens)
        all_masks.append(pad_masks)
        all_segments.append(segment_ids)
    
    return np.array(all_tokens), np.array(all_masks), np.array(all_segments)

# %%
def build_model(bert_layer, max_len=256):
    input_word_ids = tf.keras.Input(shape=(max_len,), dtype=tf.int32, name="input_word_ids")
    input_mask = tf.keras.Input(shape=(max_len,), dtype=tf.int32, name="input_mask")
    segment_ids = tf.keras.Input(shape=(max_len,), dtype=tf.int32, name="segment_ids")

    pooled_output, sequence_output = bert_layer([input_word_ids, input_mask, segment_ids])
    clf_output = sequence_output[:, 0, :]
    net = tf.keras.layers.Dense(64, activation='relu')(clf_output)
    net = tf.keras.layers.Dropout(0.2)(net)
    net = tf.keras.layers.Dense(32, activation='relu')(clf_output)
    net = tf.keras.layers.Dropout(0.2)(net)
    out = tf.keras.layers.Dense(2, activation='softmax')(net)
    
    model = tf.keras.models.Model(inputs=[input_word_ids, input_mask, segment_ids], outputs=out)
    model.compile(tf.keras.optimizers.Adam(lr=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
# complete_data_bal = complete_data_bal.sample(n = 5000)
# complete_data_bal['SENT'].value_counts()

# %%
complete_data.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 we rolled out enhancements to the godaddy payments and studio platforms along with improvements to our domain investor experience check out how we are helping small businesses grow httpsprlymsub
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      the fact that the white supremacist nations of the world feign authority over all is a real problem in my opinion as an american i can state unequivocally that we have no right to police the world when our priorities are so entirely out of line the same goes for the uk france germany canada australia and so onno child deserves this
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   if you want to know more about what is happening in iran right now please watch this video from abc by nicholas maher mahsaamini
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            together we are ending the use of neardrowning tests and saving animals from being forced to swim for their lives and we will not stop until these abusive and pointless experiments are a thing of the pastsome companies and universities completely stopped usingandor supporting others that usethe neardrowning test following actions taken by peta and our supporters including outreach by our scientists protests petaproposed shareholder resolutions and emails and calls from our supporters let us get more companies to ban the neardrowning test on animals use petas quick form to contact eli lilly todayhttpslnkdingnakfpgexperiments experiment experimentation science scienceandtechnology scientist company companies university universities highereducation protest demo demonstration shareholder shareholders shares email call animal animals animalrights animalwelfare animalcare crueltyfree saveanimals vegan govegan plantbased nonprofit nonprofitorganization advocate advocacy activist activism victory politicsandlaw socialissues
# 4  while i could not be there myself i was there in spirit cheering on the pregnant then screwed and the marchofthemummies over the past week as the over  parents and supporters took to the streets in london leeds manchester glasgow belfast cardiff exeter norwich bristol newcastle and birminghamthe coverage has looked spectacular truly raising awareness around the penalty of motherhood in the uk well done to joeli brearley and her incredibly talented teamdespite the uk being in desperate need of more people returning to work many mothers are prevented from returning to their careers by increasingly high childcare costs it is contributing to the gender pay gap  which increased in and looks as if it could do so again but that is a post for another day  and preventing women from making the most of their talents in the workplacewithout adequate funding from the government nurseries are forced to pass costs on to parents who increasingly cannot afford them new research shows that parents with the lowest incomes are having to spend three times as much on childcare as the richest the poorest parents spend  of their household earnings on childcare compared to  for the wealthiesthow utterly heartbreakinglow wages are making childcare an unattractive career option for nursery staff and childminders who are in seriously short supply while energy costs are heaping more pressure on nurseries to charge astronomical feesthis is why keeping the conversation going is vital the risk of burnout to those nursery staff and childminders is real the parents who have to take unpaid leave to be able to take care of their children are being put at an even greater disadvantage it is preventing mothers from getting back to work or progressing in their careers and widening the childcare poverty gapget involved and follow pregnant then screwed and find out about what they are doing on their website at the link in the commentsparentsatwork childcare womenatwork workingmum workingparents economysocietyworkingparentsworkingdads maternitypaypaternitypayprotestchange
#
#      LABEL  TAGS
# 0  protest    -1
# 1  protest    -1
# 2  protest    -1
# 3  protest    -1
# 4  protest    -1

# %%
# Function to convert score to sentiment
def to_sentiment(rating):
    
    rating = int(rating)
    
    # Convert to class
    if rating == -1:
        return 0
    else:
        return 1

# Apply to the dataset 
complete_data['SENT'] = complete_data.TAGS.apply(to_sentiment)

# %%
complete_data['SENT'].value_counts()
# Out:
# 0    8311
# 1    6065
# Name: SENT, dtype: int64

# %%
complete_data_bal = (complete_data.groupby('SENT', as_index=False)
        .apply(lambda x: x.sample(n=6065))
        .reset_index(drop=True))

# %%
complete_data_bal['SENT'].value_counts()
# Out:
# 0    6065
# 1    6065
# Name: SENT, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(complete_data_bal['POSTS'].values, complete_data_bal['SENT'].values, test_size = 0.25, random_state = 42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (9097,) (9097,)
# (3033,) (3033,)

# %%
max_len = 256
train_input = bert_encode(complete_data_bal['POSTS'].values, tokenizer, max_len=max_len)
test_input = bert_encode(X_test, tokenizer, max_len=max_len)
# train_labels = y_train

# %%
complete_data_bal['SENT'].values
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
train_labels = tf.keras.utils.to_categorical(complete_data_bal['SENT'].values, num_classes=2)
test_labels = tf.keras.utils.to_categorical(y_test, num_classes=2)

# %%
model = build_model(bert_layer, max_len=max_len)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_word_ids (InputLayer)    [(None, 256)]        0           []
#
#  input_mask (InputLayer)        [(None, 256)]        0           []
#
#  segment_ids (InputLayer)       [(None, 256)]        0           []
#
#  keras_layer (KerasLayer)       [(None, 768),        109482241   ['input_word_ids[0][0]',
#                                  (None, 256, 768)]                'input_mask[0][0]',
#                                                                   'segment_ids[0][0]']
#
#  tf.__operators__.getitem (Slic  (None, 768)         0           ['keras_layer[0][1]']
#  ingOpLambda)
#
#  dense_1 (Dense)                (None, 32)           24608       ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  dropout_1 (Dropout)            (None, 32)           0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 2)            66          ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 109,506,915
# Trainable params: 109,506,914
# Non-trainable params: 1
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('/content/gdrive/MyDrive/group_17/model_256_bs_16.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, verbose=1)

train_history = model.fit(
    train_input, train_labels, 
    validation_split=0.2,
    epochs=10,
    callbacks=[checkpoint, earlystopping],
    batch_size=16,
    verbose=1)
# Out:
# Epoch 1/10
# 607/607 [==============================] - ETA: 0s - loss: 0.1667 - accuracy: 0.9323
# Epoch 1: val_accuracy improved from -inf to 0.90725, saving model to /content/gdrive/MyDrive/group_17/model_256_bs_16.h5
# 607/607 [==============================] - 589s 959ms/step - loss: 0.1667 - accuracy: 0.9323 - val_loss: 0.1690 - val_accuracy: 0.9073
# Epoch 2/10
# 607/607 [==============================] - ETA: 0s - loss: 0.1104 - accuracy: 0.9560
# Epoch 2: val_accuracy did not improve from 0.90725
# 607/607 [==============================] - 568s 936ms/step - loss: 0.1104 - accuracy: 0.9560 - val_loss: 0.2222 - val_accuracy: 0.9019
# Epoch 3/10
# 607/607 [==============================] - ETA: 0s - loss: 0.0821 - accuracy: 0.9691
# Epoch 3: val_accuracy improved from 0.90725 to 0.91756, saving model to /content/gdrive/MyDrive/group_17/model_256_bs_16.h5
# 607/607 [==============================] - 582s 959ms/step - loss: 0.0821 - accuracy: 0.9691 - val_loss: 0.1980 - val_accuracy: 0.9176
# Epoch 4/10
# 607/607 [==============================] - ETA: 0s - loss: 0.0665 - accuracy: 0.9737
# Epoch 4: val_accuracy did not improve from 0.91756
# 607/607 [==============================] - 569s 937ms/step - loss: 0.0665 - accuracy: 0.9737 - val_loss: 0.2872 - val_accuracy: 0.8990
# Epoch 5/10
# 607/607 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9785
# Epoch 5: val_accuracy improved from 0.91756 to 0.92251, saving model to /content/gdrive/MyDrive/group_17/model_256_bs_16.h5
# 607/607 [==============================] - 581s 957ms/step - loss: 0.0552 - accuracy: 0.9785 - val_loss: 0.2361 - val_accuracy: 0.9225
# Epoch 6/10
# 607/607 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9792
# Epoch 6: val_accuracy did not improve from 0.92251
# 607/607 [==============================] - 568s 936ms/step - loss: 0.0487 - accuracy: 0.9792 - val_loss: 0.3680 - val_accuracy: 0.8883
# Epoch 7/10
# 607/607 [==============================] - ETA: 0s - loss: 0.0407 - accuracy: 0.9810
# Epoch 7: val_accuracy did not improve from 0.92251
# 607/607 [==============================] - 568s 936ms/step - loss: 0.0407 - accuracy: 0.9810 - val_loss: 0.3663 - val_accuracy: 0.8920
# Epoch 8/10
# 607/607 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9797
# Epoch 8: val_accuracy did not improve from 0.92251
# 607/607 [==============================] - 568s 936ms/step - loss: 0.0453 - accuracy: 0.9797 - val_loss: 0.4925 - val_accuracy: 0.8693
# Epoch 9/10
# 607/607 [==============================] - ETA: 0s - loss: 0.0401 - accuracy: 0.9819
# Epoch 9: val_accuracy did not improve from 0.92251
# 607/607 [==============================] - 568s 936ms/step - loss: 0.0401 - accuracy: 0.9819 - val_loss: 0.4056 - val_accuracy: 0.9188
# Epoch 10/10
# 607/607 [==============================] - ETA: 0s - loss: 0.0363 - accuracy: 0.9832
# Epoch 10: val_accuracy did not improve from 0.92251
# 607/607 [==============================] - 569s 937ms/step - loss: 0.0363 - accuracy: 0.9832 - val_loss: 0.5408 - val_accuracy: 0.8805
# Epoch 10: early stopping

# %%
model.load_weights('/content/gdrive/MyDrive/group_17/model_256_bs_16.h5')
test_pred = model.predict(test_input)
# Out:
# 95/95 [==============================] - 55s 536ms/step

# %%
test_pred
# Out:
# array([[6.8379500e-06, 9.9999321e-01],
#        [9.9942917e-01, 5.7078176e-04],
#        [5.1425787e-04, 9.9948573e-01],
#        ...,
#        [9.9992931e-01, 7.0655376e-05],
#        [5.5594487e-06, 9.9999440e-01],
#        [4.1793199e-05, 9.9995816e-01]], dtype=float32)

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(test_pred, axis=1)
y_true = np.argmax(test_labels, axis=1)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      1534
#            1       0.98      0.95      0.96      1499
#
#     accuracy                           0.96      3033
#    macro avg       0.96      0.96      0.96      3033
# weighted avg       0.96      0.96      0.96      3033

# %% [markdown]
# **Testing the model on completely new/unseen data**

# %%
path = "/content/gdrive/MyDrive/group_17/unseen_test_data"
dir_list = os.listdir(path)
pd.set_option('display.max_colwidth', None)

# %%
all_lines_list=list()
labels_list=list()
for filename in dir_list:
    file_extension_val=filename.split('.')
    file_extension=file_extension_val[1]
    if(file_extension=='txt'):
        label=filename.split('_')
        label=label[2]
        label=label.split('.')
        label=label[0]
        labels_list.append(label)
        # with open("/content/gdrive/MyDrive/Colab Notebooks/Unseen_test_data/"+filename, encoding='unicode_escape') as file_ptr:
        with open(path + "/" + filename, encoding='utf-8') as file_ptr:
            lines_temp = list()
            for line in file_ptr:
                if(line.strip()!="-----------------------------"):
                    lines_temp.append(line)
            all_lines_list.append(lines_temp)

# %%
df_posts=pd.DataFrame()
labels_global_list=list()
label_index=0
for lst in all_lines_list:
    df_temp = pd.DataFrame(lst)
    df_posts=df_posts.append(df_temp,ignore_index=True,)
#     label_length=len(lst)
    for i in range(len(lst)):
        labels_global_list.append(labels_list[label_index])
    label_index=label_index+1
    
df_labels = pd.DataFrame(labels_global_list)

# %%
unseen_complete_data = pd.concat([df_posts, df_labels], axis=1)
unseen_complete_data.columns = ['POSTS', 'LABEL']
unseen_complete_data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Does Excel run on Mac? You bet. So do Word, PowerPoint, and all the apps you need.\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I'm about to start a new role at Capgemini and containing myself is a real issue.Don't ask 😌#excited\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 New chapter. #excited\n
# 3     Flying away from the Nest and setting off for new adventures on the other side of the planet 🗺️This day marks a couple of important milestones:-         My first post ever on LinkedIn 🚀 (Is this really a milestone?)-         My last day working at Nestlé-         The beginning of a new and exciting journey 😍I am thrilled to announce that I’ll be moving to New Zealand as of February 2023 (#excited). Driven by the willingness to enrich ourselves as individuals, to go out of our comfort zone, to experience a new professional and personal environment, and to discover new outdoor experiences, my partner and I have decided to take that step. And why not?Since I graduated from ISIPCA in 2014, the past decade at Nestlé (wow, this sounds like a lot) which started with a 2-years internship has been incredibly rich and I feel very lucky for all the projects and experiences I went through. I met inspiring people and worked on innovative projects. From being part of the Nestlé R&D accelerator to the nesQino™️ journey, and plenty of other initiatives, I enjoyed the diversity of projects, activities, and challenges.The journey has also sometimes been punctuated with some doubts and questions, which were essential to go the extra mile. Those who know me know that I am always eager to learn new things. I don’t know yet what will come next, and I am very curious to see what the future will bring… The next two months will be busy organizing the move (and solving admin stuff), enjoying time with family and friends, recharging, and settling in New Zealand. I’ll be available for work as of February 2023 and I can’t wait to discover what New Zealand has to offer. I would love to start discussions about expatriation experiences, tips about New Zealand, potential work opportunities (including remote), …\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          #Excited about the great things to come from this partnership.  Gracias to my Omnicom Media Group familia (Geoffrey Calabrese, Kelly Metz, Amy Darwish) and TelevisaUnivision (Daniel Aversano, Richard Bertodatti) for making this happen! #multiculturalmarketing https://lnkd.in/eVpbW7CU\n
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2579                                                                                                                                                                                                                                                                                                                                                                                                                  Allowing Ourselves To Be Nurtured Let yourself be nurtured and loved.Let people be there for you.Allow yourself to be held when it would feel good.Let someone listen to you, support and encourage you when you need that.Receive comfort from someone's physical presence when you need that. Allow yourself to be supported emotionally and cared about.For too long, we've stood in the background, attending to the needs of others and claiming we have no needs of our own.We've shut off, for too long, the part of us that longs to be nurtured.It is time, now, to claim those needs, identify them, and understand that we deserve to have them met. What are our needs? What would feel good? What kinds of ways would we like others to nurture and support us?The clearer we can be about our needs, the greater the possibility they will be met.Hugs. A listening ear. Support. Encouragement.The physical and emotional presence of people who care about us.Doesn't that sound good? Tempting?No matter how old or successful we are,  we never outgrow our need for nurturing and love.Enjoyed reading this? Follow me on: https://bit.ly/3AqIY6k #couplegoals #love #loved #lovedogs #loveforever #loveislove #lovelive #lovely #lovemakeup #lovemylife #lovenature #lovequotes #lovers #loves #lovestory #lovethem #loveu #lovewhatyoudo #loveyou #loveyourbody #meditation #mindset #momlife #mylove #poetry #positivity #relationshipgoals\n
# 2580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Good morning 😊#goodmorning #goodlife #dontgiveup #win #motivational #motivationalquotes #motivationalspeaker #goodvibesonly #vibes #energy #positivemindset #positivity #sucessmindset #sucess #sucessful #quoteoftheday #quotesaboutlife #opportunites #opportunityseeker #growthopportunities #growth #goals #winner\n
# 2581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Shout out to all the men of REALSTA who despite all odds and obstacles paved the way for themselves in this over-ambitious world. May you get more strength and love. You are doing the best you can and we are all proud of you. Wishing you a very Happy International Men's Day!#internationalmensday #mensday #men #mensrights #meninist #mentoo #mgtow #mra #antifeminist #equality #antifeminism #feminism #redpill #mensmentalhealth #himtoo #mgtowisthefuture #november #equalrights #metoo #love #redpilled #mgtowforlife #meninism #boys #positivity #malepositivity\n
# 2582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              #inspiration #innovation #positivity #management #technology #success\n
# 2583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            On the latest episode of The Editing Podcast, Denise and Louise explain why they don’t share content they dislike and why it’s a good idea that you don’t, either. If you see something that doesn’t sit quite right with you, don’t spread it around — share something positive instead. 🌻Find out more about the hosts by visiting their websites. – Denise Cowle: https://lnkd.in/gzuAEwPA – Louise Harnby: https://lnkd.in/gV7wMsuZ#editing #podcast #positivity #theeditingpodcast\n
#
#            LABEL
# 0        excited
# 1        excited
# 2        excited
# 3        excited
# 4        excited
# ...          ...
# 2579  positivity
# 2580  positivity
# 2581  positivity
# 2582  positivity
# 2583  positivity
#
# [2584 rows x 2 columns]

# %%
#convert to lowercase
unseen_complete_data['POSTS']=unseen_complete_data['POSTS'].str.lower()

# %%
#remove html content
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].apply(lambda x: re.split('<[^<>]*>', str(x))[0])

# %%
def contr(post_text):
     posts_body_list=[]
     for r in post_text:
         decontract_posts_body = contractions.fix(r)
         r = ''.join(decontract_posts_body)
         r = re.sub("\s\s+", " ", r) # remove extra spaces
         posts_body_list.append(r)
     return posts_body_list

# %%
unseen_complete_data['POSTS']=contr(unseen_complete_data['POSTS'].values)

# %%
#remove non-alphabetical values
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].replace('[^a-zA-Z ]', '', regex=True)

# %%
import numpy as np
unseen_complete_data['TAGS']=np.where( (unseen_complete_data['LABEL']=='excited') | (unseen_complete_data['LABEL']=='hiring') | (unseen_complete_data['LABEL']=='positivity') | (unseen_complete_data['LABEL']=='positivevibes') | (unseen_complete_data['LABEL']=='grateful') | (unseen_complete_data['LABEL']=='newjob') | (unseen_complete_data['LABEL']=='blessed') | (unseen_complete_data['LABEL']=='happy') | (unseen_complete_data['LABEL']=='lmao') | (unseen_complete_data['LABEL']=='funny') | (unseen_complete_data['LABEL']=='fun') | (unseen_complete_data['LABEL']=='lol') , 1, -1)

# %%
unseen_complete_data=unseen_complete_data.drop_duplicates(keep='last').reset_index()

# %%
unseen_complete_data['POSTS'].replace('', np.nan, inplace=True)
unseen_complete_data.dropna(subset=['POSTS'], inplace=True)
unseen_complete_data
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 2257   2579
# 2258   2580
# 2259   2581
# 2260   2582
# 2261   2583
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 does excel run on mac you bet so do word powerpoint and all the apps you need
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i am about to start a new role at capgemini and containing myself is a real issuedo not ask excited
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           new chapter excited
# 3     flying away from the nest and setting off for new adventures on the other side of the planet this day marks a couple of important milestones my first post ever on linkedin  is this really a milestone my last day working at nestl the beginning of a new and exciting journey i am thrilled to announce that i will be moving to new zealand as of february  excited driven by the willingness to enrich ourselves as individuals to go out of our comfort zone to experience a new professional and personal environment and to discover new outdoor experiences my partner and i have decided to take that step and why notsince i graduated from isipca in  the past decade at nestl wow this sounds like a lot which started with a years internship has been incredibly rich and i feel very lucky for all the projects and experiences i went through i met inspiring people and worked on innovative projects from being part of the nestl rd accelerator to the nesqino journey and plenty of other initiatives i enjoyed the diversity of projects activities and challengesthe journey has also sometimes been punctuated with some doubts and questions which were essential to go the extra mile those who know me know that i am always eager to learn new things i do not know yet what will come next and i am very curious to see what the future will bring the next two months will be busy organizing the move and solving admin stuff enjoying time with family and friends recharging and settling in new zealand i will be available for work as of february  and i cannot wait to discover what new zealand has to offer i would love to start discussions about expatriation experiences tips about new zealand potential work opportunities including remote
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    excited about the great things to come from this partnership gracias to my omnicom media group familia geoffrey calabrese kelly metz amy darwish and televisaunivision daniel aversano richard bertodatti for making this happen multiculturalmarketing httpslnkdinevpbwcu
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 2257                                                                                                                                                                                                                                                                                                                                                                                           allowing ourselves to be nurturedlet yourself be nurtured and lovedlet people be there for youallow yourself to be held when it would feel goodlet someone listen to you support and encourage you when you need thatreceive comfort from someone is physical presence when you need that allow yourself to be supported emotionally and cared aboutfor too long we have stood in the background attending to the needs of others and claiming we have no needs of our ownwe have shut off for too long the part of us that longs to be nurturedit is time now to claim those needs identify them and understand that we deserve to have them metwhat are our needs what would feel good what kinds of ways would we like others to nurture and support usthe clearer we can be about our needs the greater the possibility they will be methugs a listening ear support encouragementthe physical and emotional presence of people who care about usdoes not that sound good temptingno matter how old or successful we are we never outgrow our need for nurturing and loveenjoyed reading this follow me on httpsbitlyaqiyk couplegoals love loved lovedogs loveforever loveislove lovelive lovely lovemakeup lovemylife lovenature lovequotes lovers loves lovestory lovethem loveu lovewhatyoudo loveyou loveyourbody meditation mindset momlife mylove poetry positivity relationshipgoals
# 2258                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning goodmorning goodlife dontgiveup win motivational motivationalquotes motivationalspeaker goodvibesonly vibes energy positivemindset positivity sucessmindset sucess sucessful quoteoftheday quotesaboutlife opportunites opportunityseeker growthopportunities growth goals winner
# 2259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                shout out to all the men of realsta who despite all odds and obstacles paved the way for themselves in this overambitious worldmay you get more strength and love you are doing the best you can and we are all proud of youwishing you a very happy international mens dayinternationalmensday mensday men mensrights meninist mentoo mgtow mra antifeminist equality antifeminism feminism redpill mensmentalhealthhimtoo mgtowisthefuture november equalrights metoo love redpilled mgtowforlife meninism boys positivity malepositivity
# 2260                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            inspiration innovation positivity management technology success
# 2261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          on the latest episode of the editing podcast denise and louise explain why they do not share content they dislike and why it is a good idea that you do not either if you see something that does not sit quite right with you do not spread it around  share something positive instead find out more about the hosts by visiting their websites  denise cowle httpslnkdingzuaewpa  louise harnby httpslnkdingvwmsuzediting podcast positivity theeditingpodcast
#
#            LABEL  TAGS
# 0        excited     1
# 1        excited     1
# 2        excited     1
# 3        excited     1
# 4        excited     1
# ...          ...   ...
# 2257  positivity     1
# 2258  positivity     1
# 2259  positivity     1
# 2260  positivity     1
# 2261  positivity     1
#
# [2255 rows x 4 columns]

# %%
unseen_complete_data['TAGS'].value_counts()
# Out:
# -1    1200
#  1    1055
# Name: TAGS, dtype: int64

# %%
# Function to convert score to sentiment
def to_sentiment(rating):
    
    rating = int(rating)
    
    # Convert to class
    if rating == -1:
        return 0
    else:
        return 1

# Apply to the dataset 
unseen_complete_data['SENT'] = unseen_complete_data.TAGS.apply(to_sentiment)

# %%
max_len = 256
unseen_input = bert_encode(unseen_complete_data['POSTS'].values, tokenizer, max_len=max_len)
# test_input = bert_encode(X_test, tokenizer, max_len=max_len)
# train_labels = y_train

# %%
unseen_labels = tf.keras.utils.to_categorical(unseen_complete_data['SENT'].values, num_classes=2)
# test_labels = tf.keras.utils.to_categorical(y_test, num_classes=2)

# %%
y_pred_unseen = model.predict(unseen_input, batch_size=16, verbose=1)
# Out:
# 141/141 [==============================] - 41s 289ms/step

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(y_pred_unseen, axis=1)
y_true = np.argmax(unseen_labels, axis=1)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88      1200
#            1       0.85      0.90      0.87      1055
#
#     accuracy                           0.88      2255
#    macro avg       0.88      0.88      0.88      2255
# weighted avg       0.88      0.88      0.88      2255

# %% [markdown]
# **Stacked GRU**

# %%
import tensorflow as tf
from tensorflow import keras
# from tensorflow.keras import layers
# from tensorflow.keras import losses
# from tensorflow.keras import preprocessing
# from tensorflow.keras import utils
# from tensorflow.keras.layers.experimental.preprocessing import TextVectorization


from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Bidirectional, Dropout, GRU
embedd_dim = 300
stacked_gru = 128
stacked_gru = keras.Sequential()
stacked_gru.add(Embedding(vocab_size, embedd_dim, weights = [w2v_embedding_matrix] , trainable = False))
stacked_gru.add(Bidirectional(GRU(128, dropout=0.2, return_sequences = True)))
stacked_gru.add(Bidirectional(GRU(64, dropout=0.2)))
stacked_gru.add(Dense(128, activation = 'relu'))
stacked_gru.add(Dropout(0.5))
stacked_gru.add(Dense(64, activation = 'relu'))
stacked_gru.add(Dropout(0.5))
stacked_gru.add(Dense(2, activation = 'softmax'))  #if used pd.get dummies above
stacked_gru.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 300)         27755100
#
#  bidirectional_2 (Bidirectio  (None, None, 256)        330240
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 128)              123648
#  nal)
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,233,886
# Trainable params: 478,786
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=10,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)
batch_size = 256
stacked_gru.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
history = stacked_gru.fit(X_train, Y_train, epochs = 50, batch_size=batch_size, verbose = 1, callbacks=[early_stopping_monitor], validation_data =(X_test, Y_test))
# Out:
# Epoch 1/50
# 43/43 [==============================] - 15s 96ms/step - loss: 0.5977 - accuracy: 0.6600 - val_loss: 0.4562 - val_accuracy: 0.7741
# Epoch 2/50
# 43/43 [==============================] - 3s 58ms/step - loss: 0.4323 - accuracy: 0.8053 - val_loss: 0.4123 - val_accuracy: 0.7924
# Epoch 3/50
# 43/43 [==============================] - 2s 58ms/step - loss: 0.3681 - accuracy: 0.8351 - val_loss: 0.3572 - val_accuracy: 0.8255
# Epoch 4/50
# 43/43 [==============================] - 3s 59ms/step - loss: 0.3599 - accuracy: 0.8320 - val_loss: 0.3463 - val_accuracy: 0.8445
# Epoch 5/50
# 43/43 [==============================] - 3s 68ms/step - loss: 0.3395 - accuracy: 0.8433 - val_loss: 0.3398 - val_accuracy: 0.8314
# Epoch 6/50
# 43/43 [==============================] - 3s 68ms/step - loss: 0.3063 - accuracy: 0.8591 - val_loss: 0.3093 - val_accuracy: 0.8523
# Epoch 7/50
# 43/43 [==============================] - 3s 81ms/step - loss: 0.2851 - accuracy: 0.8695 - val_loss: 0.3016 - val_accuracy: 0.8567
# Epoch 8/50
# 43/43 [==============================] - 3s 81ms/step - loss: 0.2772 - accuracy: 0.8700 - val_loss: 0.2990 - val_accuracy: 0.8578
# Epoch 9/50
# 43/43 [==============================] - 3s 65ms/step - loss: 0.2626 - accuracy: 0.8791 - val_loss: 0.3050 - val_accuracy: 0.8403
# Epoch 10/50
# 43/43 [==============================] - 3s 72ms/step - loss: 0.2653 - accuracy: 0.8729 - val_loss: 0.3384 - val_accuracy: 0.8400
# Epoch 11/50
# 43/43 [==============================] - 3s 68ms/step - loss: 0.2510 - accuracy: 0.8848 - val_loss: 0.2997 - val_accuracy: 0.8628
# Epoch 12/50
# 43/43 [==============================] - 3s 68ms/step - loss: 0.2332 - accuracy: 0.8886 - val_loss: 0.3046 - val_accuracy: 0.8670
# Epoch 13/50
# 43/43 [==============================] - 3s 59ms/step - loss: 0.2263 - accuracy: 0.8959 - val_loss: 0.3157 - val_accuracy: 0.8603
# Epoch 14/50
# 43/43 [==============================] - 2s 57ms/step - loss: 0.2233 - accuracy: 0.8959 - val_loss: 0.3209 - val_accuracy: 0.8570
# Epoch 15/50
# 43/43 [==============================] - 3s 68ms/step - loss: 0.2105 - accuracy: 0.8994 - val_loss: 0.3092 - val_accuracy: 0.8651
# Epoch 16/50
# 43/43 [==============================] - 2s 55ms/step - loss: 0.2019 - accuracy: 0.9045 - val_loss: 0.3276 - val_accuracy: 0.8659
# Epoch 17/50
# 43/43 [==============================] - 2s 55ms/step - loss: 0.2030 - accuracy: 0.9051 - val_loss: 0.3243 - val_accuracy: 0.8637
# Epoch 18/50
# 43/43 [==============================] - 2s 56ms/step - loss: 0.2076 - accuracy: 0.9043 - val_loss: 0.3621 - val_accuracy: 0.8495

# %%
stacked_gru.save('/content/gdrive/MyDrive/group_17/bi_gru_w2v')
stacked_gru.save_weights(filepath='/content/gdrive/MyDrive/group_17/bi_gru_w2v.h5')
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_7_layer_call_fn, gru_cell_7_layer_call_and_return_conditional_losses, gru_cell_8_layer_call_fn, gru_cell_8_layer_call_and_return_conditional_losses, gru_cell_10_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.

# %%
stacked_gru = tf.keras.models.load_model('/content/gdrive/MyDrive/group_17/bi_gru_w2v')

stacked_gru.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 300)         27755100
#
#  bidirectional_2 (Bidirectio  (None, None, 256)        330240
#  nal)
#
#  bidirectional_3 (Bidirectio  (None, 128)              123648
#  nal)
#
#  dense (Dense)               (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 28,233,886
# Trainable params: 478,786
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
Y_test_new=[]
for val in Y_test:
  if val[0]==1:
    Y_test_new.append(0)
  else:
    Y_test_new.append(1)

# %%
from sklearn.metrics import classification_report

y_pred = stacked_gru.predict(X_test, batch_size=64, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)

print(classification_report(Y_test_new, y_pred_bool))
# Out:
# 57/57 [==============================] - 2s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88      2098
#            1       0.84      0.81      0.83      1496
#
#     accuracy                           0.86      3594
#    macro avg       0.85      0.85      0.85      3594
# weighted avg       0.86      0.86      0.86      3594

# %% [markdown]
# **Testing the model on completely new/unseen data**

# %%
path = "/content/gdrive/MyDrive/group_17/unseen_test_data"
dir_list = os.listdir(path)
pd.set_option('display.max_colwidth', None)

# %%
all_lines_list=list()
labels_list=list()
for filename in dir_list:
    file_extension_val=filename.split('.')
    file_extension=file_extension_val[1]
    if(file_extension=='txt'):
        label=filename.split('_')
        label=label[2]
        label=label.split('.')
        label=label[0]
        labels_list.append(label)
        # with open("/content/gdrive/MyDrive/Colab Notebooks/Unseen_test_data/"+filename, encoding='unicode_escape') as file_ptr:
        with open(path + "/" + filename, encoding='utf-8') as file_ptr:
            lines_temp = list()
            for line in file_ptr:
                if(line.strip()!="-----------------------------"):
                    lines_temp.append(line)
            all_lines_list.append(lines_temp)

# %%
df_posts=pd.DataFrame()
labels_global_list=list()
label_index=0
for lst in all_lines_list:
    df_temp = pd.DataFrame(lst)
    df_posts=df_posts.append(df_temp,ignore_index=True,)
#     label_length=len(lst)
    for i in range(len(lst)):
        labels_global_list.append(labels_list[label_index])
    label_index=label_index+1
    
df_labels = pd.DataFrame(labels_global_list)

# %%
unseen_complete_data = pd.concat([df_posts, df_labels], axis=1)
unseen_complete_data.columns = ['POSTS', 'LABEL']
unseen_complete_data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Does Excel run on Mac? You bet. So do Word, PowerPoint, and all the apps you need.\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I'm about to start a new role at Capgemini and containing myself is a real issue.Don't ask 😌#excited\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 New chapter. #excited\n
# 3     Flying away from the Nest and setting off for new adventures on the other side of the planet 🗺️This day marks a couple of important milestones:-         My first post ever on LinkedIn 🚀 (Is this really a milestone?)-         My last day working at Nestlé-         The beginning of a new and exciting journey 😍I am thrilled to announce that I’ll be moving to New Zealand as of February 2023 (#excited). Driven by the willingness to enrich ourselves as individuals, to go out of our comfort zone, to experience a new professional and personal environment, and to discover new outdoor experiences, my partner and I have decided to take that step. And why not?Since I graduated from ISIPCA in 2014, the past decade at Nestlé (wow, this sounds like a lot) which started with a 2-years internship has been incredibly rich and I feel very lucky for all the projects and experiences I went through. I met inspiring people and worked on innovative projects. From being part of the Nestlé R&D accelerator to the nesQino™️ journey, and plenty of other initiatives, I enjoyed the diversity of projects, activities, and challenges.The journey has also sometimes been punctuated with some doubts and questions, which were essential to go the extra mile. Those who know me know that I am always eager to learn new things. I don’t know yet what will come next, and I am very curious to see what the future will bring… The next two months will be busy organizing the move (and solving admin stuff), enjoying time with family and friends, recharging, and settling in New Zealand. I’ll be available for work as of February 2023 and I can’t wait to discover what New Zealand has to offer. I would love to start discussions about expatriation experiences, tips about New Zealand, potential work opportunities (including remote), …\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          #Excited about the great things to come from this partnership.  Gracias to my Omnicom Media Group familia (Geoffrey Calabrese, Kelly Metz, Amy Darwish) and TelevisaUnivision (Daniel Aversano, Richard Bertodatti) for making this happen! #multiculturalmarketing https://lnkd.in/eVpbW7CU\n
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2579                                                                                                                                                                                                                                                                                                                                                                                                                  Allowing Ourselves To Be Nurtured Let yourself be nurtured and loved.Let people be there for you.Allow yourself to be held when it would feel good.Let someone listen to you, support and encourage you when you need that.Receive comfort from someone's physical presence when you need that. Allow yourself to be supported emotionally and cared about.For too long, we've stood in the background, attending to the needs of others and claiming we have no needs of our own.We've shut off, for too long, the part of us that longs to be nurtured.It is time, now, to claim those needs, identify them, and understand that we deserve to have them met. What are our needs? What would feel good? What kinds of ways would we like others to nurture and support us?The clearer we can be about our needs, the greater the possibility they will be met.Hugs. A listening ear. Support. Encouragement.The physical and emotional presence of people who care about us.Doesn't that sound good? Tempting?No matter how old or successful we are,  we never outgrow our need for nurturing and love.Enjoyed reading this? Follow me on: https://bit.ly/3AqIY6k #couplegoals #love #loved #lovedogs #loveforever #loveislove #lovelive #lovely #lovemakeup #lovemylife #lovenature #lovequotes #lovers #loves #lovestory #lovethem #loveu #lovewhatyoudo #loveyou #loveyourbody #meditation #mindset #momlife #mylove #poetry #positivity #relationshipgoals\n
# 2580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Good morning 😊#goodmorning #goodlife #dontgiveup #win #motivational #motivationalquotes #motivationalspeaker #goodvibesonly #vibes #energy #positivemindset #positivity #sucessmindset #sucess #sucessful #quoteoftheday #quotesaboutlife #opportunites #opportunityseeker #growthopportunities #growth #goals #winner\n
# 2581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Shout out to all the men of REALSTA who despite all odds and obstacles paved the way for themselves in this over-ambitious world. May you get more strength and love. You are doing the best you can and we are all proud of you. Wishing you a very Happy International Men's Day!#internationalmensday #mensday #men #mensrights #meninist #mentoo #mgtow #mra #antifeminist #equality #antifeminism #feminism #redpill #mensmentalhealth #himtoo #mgtowisthefuture #november #equalrights #metoo #love #redpilled #mgtowforlife #meninism #boys #positivity #malepositivity\n
# 2582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              #inspiration #innovation #positivity #management #technology #success\n
# 2583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            On the latest episode of The Editing Podcast, Denise and Louise explain why they don’t share content they dislike and why it’s a good idea that you don’t, either. If you see something that doesn’t sit quite right with you, don’t spread it around — share something positive instead. 🌻Find out more about the hosts by visiting their websites. – Denise Cowle: https://lnkd.in/gzuAEwPA – Louise Harnby: https://lnkd.in/gV7wMsuZ#editing #podcast #positivity #theeditingpodcast\n
#
#            LABEL
# 0        excited
# 1        excited
# 2        excited
# 3        excited
# 4        excited
# ...          ...
# 2579  positivity
# 2580  positivity
# 2581  positivity
# 2582  positivity
# 2583  positivity
#
# [2584 rows x 2 columns]

# %%
#convert to lowercase
unseen_complete_data['POSTS']=unseen_complete_data['POSTS'].str.lower()

# %%
#remove html content
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].apply(lambda x: re.split('<[^<>]*>', str(x))[0])

# %%
def contr(post_text):
     posts_body_list=[]
     for r in post_text:
         decontract_posts_body = contractions.fix(r)
         r = ''.join(decontract_posts_body)
         r = re.sub("\s\s+", " ", r) # remove extra spaces
         posts_body_list.append(r)
     return posts_body_list

# %%
unseen_complete_data['POSTS']=contr(unseen_complete_data['POSTS'].values)

# %%
#remove non-alphabetical values
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].replace('[^a-zA-Z ]', '', regex=True)

# %%
import numpy as np
unseen_complete_data['TAGS']=np.where( (unseen_complete_data['LABEL']=='excited') | (unseen_complete_data['LABEL']=='hiring') | (unseen_complete_data['LABEL']=='positivity') | (unseen_complete_data['LABEL']=='positivevibes') | (unseen_complete_data['LABEL']=='grateful') | (unseen_complete_data['LABEL']=='newjob') | (unseen_complete_data['LABEL']=='blessed') | (unseen_complete_data['LABEL']=='happy') | (unseen_complete_data['LABEL']=='lmao') | (unseen_complete_data['LABEL']=='funny') | (unseen_complete_data['LABEL']=='fun') | (unseen_complete_data['LABEL']=='lol') , 1, -1)

# %%
unseen_complete_data=unseen_complete_data.drop_duplicates(keep='last').reset_index()

# %%
unseen_complete_data['POSTS'].replace('', np.nan, inplace=True)
unseen_complete_data.dropna(subset=['POSTS'], inplace=True)
unseen_complete_data
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 2257   2579
# 2258   2580
# 2259   2581
# 2260   2582
# 2261   2583
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 does excel run on mac you bet so do word powerpoint and all the apps you need
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i am about to start a new role at capgemini and containing myself is a real issuedo not ask excited
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           new chapter excited
# 3     flying away from the nest and setting off for new adventures on the other side of the planet this day marks a couple of important milestones my first post ever on linkedin  is this really a milestone my last day working at nestl the beginning of a new and exciting journey i am thrilled to announce that i will be moving to new zealand as of february  excited driven by the willingness to enrich ourselves as individuals to go out of our comfort zone to experience a new professional and personal environment and to discover new outdoor experiences my partner and i have decided to take that step and why notsince i graduated from isipca in  the past decade at nestl wow this sounds like a lot which started with a years internship has been incredibly rich and i feel very lucky for all the projects and experiences i went through i met inspiring people and worked on innovative projects from being part of the nestl rd accelerator to the nesqino journey and plenty of other initiatives i enjoyed the diversity of projects activities and challengesthe journey has also sometimes been punctuated with some doubts and questions which were essential to go the extra mile those who know me know that i am always eager to learn new things i do not know yet what will come next and i am very curious to see what the future will bring the next two months will be busy organizing the move and solving admin stuff enjoying time with family and friends recharging and settling in new zealand i will be available for work as of february  and i cannot wait to discover what new zealand has to offer i would love to start discussions about expatriation experiences tips about new zealand potential work opportunities including remote
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    excited about the great things to come from this partnership gracias to my omnicom media group familia geoffrey calabrese kelly metz amy darwish and televisaunivision daniel aversano richard bertodatti for making this happen multiculturalmarketing httpslnkdinevpbwcu
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 2257                                                                                                                                                                                                                                                                                                                                                                                           allowing ourselves to be nurturedlet yourself be nurtured and lovedlet people be there for youallow yourself to be held when it would feel goodlet someone listen to you support and encourage you when you need thatreceive comfort from someone is physical presence when you need that allow yourself to be supported emotionally and cared aboutfor too long we have stood in the background attending to the needs of others and claiming we have no needs of our ownwe have shut off for too long the part of us that longs to be nurturedit is time now to claim those needs identify them and understand that we deserve to have them metwhat are our needs what would feel good what kinds of ways would we like others to nurture and support usthe clearer we can be about our needs the greater the possibility they will be methugs a listening ear support encouragementthe physical and emotional presence of people who care about usdoes not that sound good temptingno matter how old or successful we are we never outgrow our need for nurturing and loveenjoyed reading this follow me on httpsbitlyaqiyk couplegoals love loved lovedogs loveforever loveislove lovelive lovely lovemakeup lovemylife lovenature lovequotes lovers loves lovestory lovethem loveu lovewhatyoudo loveyou loveyourbody meditation mindset momlife mylove poetry positivity relationshipgoals
# 2258                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning goodmorning goodlife dontgiveup win motivational motivationalquotes motivationalspeaker goodvibesonly vibes energy positivemindset positivity sucessmindset sucess sucessful quoteoftheday quotesaboutlife opportunites opportunityseeker growthopportunities growth goals winner
# 2259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                shout out to all the men of realsta who despite all odds and obstacles paved the way for themselves in this overambitious worldmay you get more strength and love you are doing the best you can and we are all proud of youwishing you a very happy international mens dayinternationalmensday mensday men mensrights meninist mentoo mgtow mra antifeminist equality antifeminism feminism redpill mensmentalhealthhimtoo mgtowisthefuture november equalrights metoo love redpilled mgtowforlife meninism boys positivity malepositivity
# 2260                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            inspiration innovation positivity management technology success
# 2261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          on the latest episode of the editing podcast denise and louise explain why they do not share content they dislike and why it is a good idea that you do not either if you see something that does not sit quite right with you do not spread it around  share something positive instead find out more about the hosts by visiting their websites  denise cowle httpslnkdingzuaewpa  louise harnby httpslnkdingvwmsuzediting podcast positivity theeditingpodcast
#
#            LABEL  TAGS
# 0        excited     1
# 1        excited     1
# 2        excited     1
# 3        excited     1
# 4        excited     1
# ...          ...   ...
# 2257  positivity     1
# 2258  positivity     1
# 2259  positivity     1
# 2260  positivity     1
# 2261  positivity     1
#
# [2255 rows x 4 columns]

# %%
unseen_complete_data['TAGS'].value_counts()
# Out:
# -1    1200
#  1    1055
# Name: TAGS, dtype: int64

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
#max_features = 2000
#tokenizer = Tokenizer(num_words = max_features, )
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(unseen_complete_data['POSTS'].values)
X = tokenizer.texts_to_sequences(unseen_complete_data['POSTS'].values)
X = pad_sequences(X, padding = 'post' , maxlen=100)
Y = pd.get_dummies(unseen_complete_data['TAGS']).values
#Y= complete_data['TAGS'].values

vocab_size = len(tokenizer.word_index)+1

# %%
# w2v test
te_w2v_embedding_matrix = np.zeros((vocab_size,300))
for word,i in tqdm(tokenizer.word_index.items()):
    embedding_value = word2vec_dict.get(word)
    te_w2v_embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 92516/92516 [00:01<00:00, 82088.35it/s]

# %%
Y_test_new_unseen=[]
for val in Y:
  if val[0]==1:
    Y_test_new_unseen.append(0)
  else:
    Y_test_new_unseen.append(1)

# %%
from sklearn.metrics import classification_report

y_pred_unseen = stacked_gru.predict(X, batch_size=10, verbose=1)
y_pred_bool_unseen = np.argmax(y_pred_unseen, axis=1)

print(classification_report(Y_test_new_unseen, y_pred_bool_unseen))
# Out:
# 226/226 [==============================] - 3s 12ms/step
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86      1200
#            1       0.85      0.82      0.83      1055
#
#     accuracy                           0.85      2255
#    macro avg       0.85      0.85      0.85      2255
# weighted avg       0.85      0.85      0.85      2255

# %% [markdown]
# **Stacked GRU-LSTM**

# %%
import tensorflow as tf
from tensorflow import keras
# from tensorflow.keras import layers
# from tensorflow.keras import losses
# from tensorflow.keras import preprocessing
# from tensorflow.keras import utils
# from tensorflow.keras.layers.experimental.preprocessing import TextVectorization


from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D, Bidirectional, Dropout, GRU
embedd_dim = 300
stacked_gru_lstm = 128
stacked_gru_lstm = keras.Sequential()
stacked_gru_lstm.add(Embedding(vocab_size, embedd_dim, weights = [w2v_embedding_matrix] , trainable = False))
stacked_gru_lstm.add(Bidirectional(GRU(256, dropout=0.2, return_sequences = True)))
stacked_gru_lstm.add(Bidirectional(GRU(128, dropout=0.2, return_sequences = True)))
stacked_gru_lstm.add(Bidirectional(LSTM(64, dropout=0.2, return_sequences = True)))
stacked_gru_lstm.add(Bidirectional(GRU(32, dropout=0.2)))
stacked_gru_lstm.add(Dense(128, activation = 'relu'))
stacked_gru_lstm.add(Dropout(0.2))
stacked_gru_lstm.add(Dense(64, activation = 'relu'))
stacked_gru_lstm.add(Dropout(0.2))
stacked_gru_lstm.add(Dense(2, activation = 'softmax'))  #if used pd.get dummies above
stacked_gru_lstm.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, None, 300)         27755100
#
#  bidirectional_20 (Bidirecti  (None, None, 512)        857088
#  onal)
#
#  bidirectional_21 (Bidirecti  (None, None, 256)        493056
#  onal)
#
#  bidirectional_22 (Bidirecti  (None, None, 128)        164352
#  onal)
#
#  bidirectional_23 (Bidirecti  (None, 64)               31104
#  onal)
#
#  dense_15 (Dense)            (None, 128)               8320
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 29,317,406
# Trainable params: 1,562,306
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
early_stopping_monitor = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0,
    patience=10,
    verbose=0,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)
batch_size = 256
stacked_gru_lstm.compile(loss = 'binary_crossentropy', optimizer='adam',metrics = ['accuracy'])
history = stacked_gru_lstm.fit(X_train, Y_train, epochs = 50, batch_size=batch_size, verbose = 1, callbacks=[early_stopping_monitor], validation_data =(X_test, Y_test))
# Out:
# Epoch 1/50
# 43/43 [==============================] - 21s 240ms/step - loss: 0.5517 - accuracy: 0.7107 - val_loss: 0.4495 - val_accuracy: 0.7682
# Epoch 2/50
# 43/43 [==============================] - 6s 145ms/step - loss: 0.4364 - accuracy: 0.7960 - val_loss: 0.4688 - val_accuracy: 0.7549
# Epoch 3/50
# 43/43 [==============================] - 6s 149ms/step - loss: 0.4013 - accuracy: 0.8133 - val_loss: 0.4100 - val_accuracy: 0.7919
# Epoch 4/50
# 43/43 [==============================] - 6s 150ms/step - loss: 0.3786 - accuracy: 0.8222 - val_loss: 0.3533 - val_accuracy: 0.8397
# Epoch 5/50
# 43/43 [==============================] - 6s 151ms/step - loss: 0.3405 - accuracy: 0.8249 - val_loss: 0.3156 - val_accuracy: 0.8459
# Epoch 6/50
# 43/43 [==============================] - 6s 148ms/step - loss: 0.3113 - accuracy: 0.8462 - val_loss: 0.3215 - val_accuracy: 0.8397
# Epoch 7/50
# 43/43 [==============================] - 6s 150ms/step - loss: 0.2945 - accuracy: 0.8573 - val_loss: 0.2872 - val_accuracy: 0.8548
# Epoch 8/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.2779 - accuracy: 0.8616 - val_loss: 0.3055 - val_accuracy: 0.8411
# Epoch 9/50
# 43/43 [==============================] - 6s 148ms/step - loss: 0.2652 - accuracy: 0.8724 - val_loss: 0.2829 - val_accuracy: 0.8600
# Epoch 10/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.2556 - accuracy: 0.8761 - val_loss: 0.2730 - val_accuracy: 0.8692
# Epoch 11/50
# 43/43 [==============================] - 6s 145ms/step - loss: 0.2524 - accuracy: 0.8779 - val_loss: 0.2836 - val_accuracy: 0.8662
# Epoch 12/50
# 43/43 [==============================] - 6s 150ms/step - loss: 0.2450 - accuracy: 0.8836 - val_loss: 0.2765 - val_accuracy: 0.8701
# Epoch 13/50
# 43/43 [==============================] - 6s 145ms/step - loss: 0.2309 - accuracy: 0.8909 - val_loss: 0.2860 - val_accuracy: 0.8628
# Epoch 14/50
# 43/43 [==============================] - 7s 159ms/step - loss: 0.2313 - accuracy: 0.8917 - val_loss: 0.2742 - val_accuracy: 0.8698
# Epoch 15/50
# 43/43 [==============================] - 7s 161ms/step - loss: 0.2176 - accuracy: 0.8968 - val_loss: 0.2700 - val_accuracy: 0.8662
# Epoch 16/50
# 43/43 [==============================] - 6s 146ms/step - loss: 0.2162 - accuracy: 0.8998 - val_loss: 0.2816 - val_accuracy: 0.8734
# Epoch 17/50
# 43/43 [==============================] - 6s 146ms/step - loss: 0.2058 - accuracy: 0.9070 - val_loss: 0.2841 - val_accuracy: 0.8765
# Epoch 18/50
# 43/43 [==============================] - 6s 149ms/step - loss: 0.1950 - accuracy: 0.9091 - val_loss: 0.2844 - val_accuracy: 0.8742
# Epoch 19/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.1914 - accuracy: 0.9141 - val_loss: 0.2939 - val_accuracy: 0.8756
# Epoch 20/50
# 43/43 [==============================] - 6s 146ms/step - loss: 0.1754 - accuracy: 0.9224 - val_loss: 0.3123 - val_accuracy: 0.8712
# Epoch 21/50
# 43/43 [==============================] - 6s 146ms/step - loss: 0.1781 - accuracy: 0.9156 - val_loss: 0.2947 - val_accuracy: 0.8798
# Epoch 22/50
# 43/43 [==============================] - 6s 146ms/step - loss: 0.1652 - accuracy: 0.9228 - val_loss: 0.3390 - val_accuracy: 0.8776
# Epoch 23/50
# 43/43 [==============================] - 6s 145ms/step - loss: 0.1586 - accuracy: 0.9298 - val_loss: 0.3498 - val_accuracy: 0.8709
# Epoch 24/50
# 43/43 [==============================] - 6s 146ms/step - loss: 0.1494 - accuracy: 0.9358 - val_loss: 0.3068 - val_accuracy: 0.8787
# Epoch 25/50
# 43/43 [==============================] - 6s 147ms/step - loss: 0.1389 - accuracy: 0.9387 - val_loss: 0.3557 - val_accuracy: 0.8717

# %%
stacked_gru_lstm.save('/content/gdrive/MyDrive/group_17/bi_gru_lstm_w2v')
stacked_gru_lstm.save_weights(filepath='/content/gdrive/MyDrive/group_17/bi_gru_lstm_w2v.h5')
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_55_layer_call_fn, gru_cell_55_layer_call_and_return_conditional_losses, gru_cell_56_layer_call_fn, gru_cell_56_layer_call_and_return_conditional_losses, gru_cell_58_layer_call_fn while saving (showing 5 of 16). These functions will not be directly callable after loading.

# %%
stacked_gru_lstm = tf.keras.models.load_model('/content/gdrive/MyDrive/group_17/bi_gru_lstm_w2v')

stacked_gru_lstm.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_6 (Embedding)     (None, None, 300)         27755100
#
#  bidirectional_20 (Bidirecti  (None, None, 512)        857088
#  onal)
#
#  bidirectional_21 (Bidirecti  (None, None, 256)        493056
#  onal)
#
#  bidirectional_22 (Bidirecti  (None, None, 128)        164352
#  onal)
#
#  bidirectional_23 (Bidirecti  (None, 64)               31104
#  onal)
#
#  dense_15 (Dense)            (None, 128)               8320
#
#  dropout_10 (Dropout)        (None, 128)               0
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dropout_11 (Dropout)        (None, 64)                0
#
#  dense_17 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 29,317,406
# Trainable params: 1,562,306
# Non-trainable params: 27,755,100
# _________________________________________________________________

# %%
Y_test_new=[]
for val in Y_test:
  if val[0]==1:
    Y_test_new.append(0)
  else:
    Y_test_new.append(1)

# %%
from sklearn.metrics import classification_report

y_pred = stacked_gru_lstm.predict(X_test, batch_size=64, verbose=1)
y_pred_bool = np.argmax(y_pred, axis=1)

print(classification_report(Y_test_new, y_pred_bool))
# Out:
# 57/57 [==============================] - 4s 23ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      2098
#            1       0.83      0.85      0.84      1496
#
#     accuracy                           0.87      3594
#    macro avg       0.86      0.86      0.86      3594
# weighted avg       0.87      0.87      0.87      3594

# %% [markdown]
# **Testing the model on completely new/unseen data**

# %%
path = "/content/gdrive/MyDrive/group_17/unseen_test_data"
dir_list = os.listdir(path)
pd.set_option('display.max_colwidth', None)

# %%
all_lines_list=list()
labels_list=list()
for filename in dir_list:
    file_extension_val=filename.split('.')
    file_extension=file_extension_val[1]
    if(file_extension=='txt'):
        label=filename.split('_')
        label=label[2]
        label=label.split('.')
        label=label[0]
        labels_list.append(label)
        # with open("/content/gdrive/MyDrive/Colab Notebooks/Unseen_test_data/"+filename, encoding='unicode_escape') as file_ptr:
        with open(path + "/" + filename, encoding='utf-8') as file_ptr:
            lines_temp = list()
            for line in file_ptr:
                if(line.strip()!="-----------------------------"):
                    lines_temp.append(line)
            all_lines_list.append(lines_temp)

# %%
df_posts=pd.DataFrame()
labels_global_list=list()
label_index=0
for lst in all_lines_list:
    df_temp = pd.DataFrame(lst)
    df_posts=df_posts.append(df_temp,ignore_index=True,)
#     label_length=len(lst)
    for i in range(len(lst)):
        labels_global_list.append(labels_list[label_index])
    label_index=label_index+1
    
df_labels = pd.DataFrame(labels_global_list)

# %%
unseen_complete_data = pd.concat([df_posts, df_labels], axis=1)
unseen_complete_data.columns = ['POSTS', 'LABEL']
unseen_complete_data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Does Excel run on Mac? You bet. So do Word, PowerPoint, and all the apps you need.\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I'm about to start a new role at Capgemini and containing myself is a real issue.Don't ask 😌#excited\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 New chapter. #excited\n
# 3     Flying away from the Nest and setting off for new adventures on the other side of the planet 🗺️This day marks a couple of important milestones:-         My first post ever on LinkedIn 🚀 (Is this really a milestone?)-         My last day working at Nestlé-         The beginning of a new and exciting journey 😍I am thrilled to announce that I’ll be moving to New Zealand as of February 2023 (#excited). Driven by the willingness to enrich ourselves as individuals, to go out of our comfort zone, to experience a new professional and personal environment, and to discover new outdoor experiences, my partner and I have decided to take that step. And why not?Since I graduated from ISIPCA in 2014, the past decade at Nestlé (wow, this sounds like a lot) which started with a 2-years internship has been incredibly rich and I feel very lucky for all the projects and experiences I went through. I met inspiring people and worked on innovative projects. From being part of the Nestlé R&D accelerator to the nesQino™️ journey, and plenty of other initiatives, I enjoyed the diversity of projects, activities, and challenges.The journey has also sometimes been punctuated with some doubts and questions, which were essential to go the extra mile. Those who know me know that I am always eager to learn new things. I don’t know yet what will come next, and I am very curious to see what the future will bring… The next two months will be busy organizing the move (and solving admin stuff), enjoying time with family and friends, recharging, and settling in New Zealand. I’ll be available for work as of February 2023 and I can’t wait to discover what New Zealand has to offer. I would love to start discussions about expatriation experiences, tips about New Zealand, potential work opportunities (including remote), …\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          #Excited about the great things to come from this partnership.  Gracias to my Omnicom Media Group familia (Geoffrey Calabrese, Kelly Metz, Amy Darwish) and TelevisaUnivision (Daniel Aversano, Richard Bertodatti) for making this happen! #multiculturalmarketing https://lnkd.in/eVpbW7CU\n
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2579                                                                                                                                                                                                                                                                                                                                                                                                                  Allowing Ourselves To Be Nurtured Let yourself be nurtured and loved.Let people be there for you.Allow yourself to be held when it would feel good.Let someone listen to you, support and encourage you when you need that.Receive comfort from someone's physical presence when you need that. Allow yourself to be supported emotionally and cared about.For too long, we've stood in the background, attending to the needs of others and claiming we have no needs of our own.We've shut off, for too long, the part of us that longs to be nurtured.It is time, now, to claim those needs, identify them, and understand that we deserve to have them met. What are our needs? What would feel good? What kinds of ways would we like others to nurture and support us?The clearer we can be about our needs, the greater the possibility they will be met.Hugs. A listening ear. Support. Encouragement.The physical and emotional presence of people who care about us.Doesn't that sound good? Tempting?No matter how old or successful we are,  we never outgrow our need for nurturing and love.Enjoyed reading this? Follow me on: https://bit.ly/3AqIY6k #couplegoals #love #loved #lovedogs #loveforever #loveislove #lovelive #lovely #lovemakeup #lovemylife #lovenature #lovequotes #lovers #loves #lovestory #lovethem #loveu #lovewhatyoudo #loveyou #loveyourbody #meditation #mindset #momlife #mylove #poetry #positivity #relationshipgoals\n
# 2580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Good morning 😊#goodmorning #goodlife #dontgiveup #win #motivational #motivationalquotes #motivationalspeaker #goodvibesonly #vibes #energy #positivemindset #positivity #sucessmindset #sucess #sucessful #quoteoftheday #quotesaboutlife #opportunites #opportunityseeker #growthopportunities #growth #goals #winner\n
# 2581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Shout out to all the men of REALSTA who despite all odds and obstacles paved the way for themselves in this over-ambitious world. May you get more strength and love. You are doing the best you can and we are all proud of you. Wishing you a very Happy International Men's Day!#internationalmensday #mensday #men #mensrights #meninist #mentoo #mgtow #mra #antifeminist #equality #antifeminism #feminism #redpill #mensmentalhealth #himtoo #mgtowisthefuture #november #equalrights #metoo #love #redpilled #mgtowforlife #meninism #boys #positivity #malepositivity\n
# 2582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              #inspiration #innovation #positivity #management #technology #success\n
# 2583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            On the latest episode of The Editing Podcast, Denise and Louise explain why they don’t share content they dislike and why it’s a good idea that you don’t, either. If you see something that doesn’t sit quite right with you, don’t spread it around — share something positive instead. 🌻Find out more about the hosts by visiting their websites. – Denise Cowle: https://lnkd.in/gzuAEwPA – Louise Harnby: https://lnkd.in/gV7wMsuZ#editing #podcast #positivity #theeditingpodcast\n
#
#            LABEL
# 0        excited
# 1        excited
# 2        excited
# 3        excited
# 4        excited
# ...          ...
# 2579  positivity
# 2580  positivity
# 2581  positivity
# 2582  positivity
# 2583  positivity
#
# [2584 rows x 2 columns]

# %%
#convert to lowercase
unseen_complete_data['POSTS']=unseen_complete_data['POSTS'].str.lower()

# %%
#remove html content
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].apply(lambda x: re.split('<[^<>]*>', str(x))[0])

# %%
def contr(post_text):
     posts_body_list=[]
     for r in post_text:
         decontract_posts_body = contractions.fix(r)
         r = ''.join(decontract_posts_body)
         r = re.sub("\s\s+", " ", r) # remove extra spaces
         posts_body_list.append(r)
     return posts_body_list

# %%
unseen_complete_data['POSTS']=contr(unseen_complete_data['POSTS'].values)

# %%
#remove non-alphabetical values
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].replace('[^a-zA-Z ]', '', regex=True)

# %%
import numpy as np
unseen_complete_data['TAGS']=np.where( (unseen_complete_data['LABEL']=='excited') | (unseen_complete_data['LABEL']=='hiring') | (unseen_complete_data['LABEL']=='positivity') | (unseen_complete_data['LABEL']=='positivevibes') | (unseen_complete_data['LABEL']=='grateful') | (unseen_complete_data['LABEL']=='newjob') | (unseen_complete_data['LABEL']=='blessed') | (unseen_complete_data['LABEL']=='happy') | (unseen_complete_data['LABEL']=='lmao') | (unseen_complete_data['LABEL']=='funny') | (unseen_complete_data['LABEL']=='fun') | (unseen_complete_data['LABEL']=='lol') , 1, -1)

# %%
unseen_complete_data=unseen_complete_data.drop_duplicates(keep='last').reset_index()

# %%
unseen_complete_data['POSTS'].replace('', np.nan, inplace=True)
unseen_complete_data.dropna(subset=['POSTS'], inplace=True)
unseen_complete_data
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 2257   2579
# 2258   2580
# 2259   2581
# 2260   2582
# 2261   2583
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 does excel run on mac you bet so do word powerpoint and all the apps you need
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i am about to start a new role at capgemini and containing myself is a real issuedo not ask excited
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           new chapter excited
# 3     flying away from the nest and setting off for new adventures on the other side of the planet this day marks a couple of important milestones my first post ever on linkedin  is this really a milestone my last day working at nestl the beginning of a new and exciting journey i am thrilled to announce that i will be moving to new zealand as of february  excited driven by the willingness to enrich ourselves as individuals to go out of our comfort zone to experience a new professional and personal environment and to discover new outdoor experiences my partner and i have decided to take that step and why notsince i graduated from isipca in  the past decade at nestl wow this sounds like a lot which started with a years internship has been incredibly rich and i feel very lucky for all the projects and experiences i went through i met inspiring people and worked on innovative projects from being part of the nestl rd accelerator to the nesqino journey and plenty of other initiatives i enjoyed the diversity of projects activities and challengesthe journey has also sometimes been punctuated with some doubts and questions which were essential to go the extra mile those who know me know that i am always eager to learn new things i do not know yet what will come next and i am very curious to see what the future will bring the next two months will be busy organizing the move and solving admin stuff enjoying time with family and friends recharging and settling in new zealand i will be available for work as of february  and i cannot wait to discover what new zealand has to offer i would love to start discussions about expatriation experiences tips about new zealand potential work opportunities including remote
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    excited about the great things to come from this partnership gracias to my omnicom media group familia geoffrey calabrese kelly metz amy darwish and televisaunivision daniel aversano richard bertodatti for making this happen multiculturalmarketing httpslnkdinevpbwcu
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 2257                                                                                                                                                                                                                                                                                                                                                                                           allowing ourselves to be nurturedlet yourself be nurtured and lovedlet people be there for youallow yourself to be held when it would feel goodlet someone listen to you support and encourage you when you need thatreceive comfort from someone is physical presence when you need that allow yourself to be supported emotionally and cared aboutfor too long we have stood in the background attending to the needs of others and claiming we have no needs of our ownwe have shut off for too long the part of us that longs to be nurturedit is time now to claim those needs identify them and understand that we deserve to have them metwhat are our needs what would feel good what kinds of ways would we like others to nurture and support usthe clearer we can be about our needs the greater the possibility they will be methugs a listening ear support encouragementthe physical and emotional presence of people who care about usdoes not that sound good temptingno matter how old or successful we are we never outgrow our need for nurturing and loveenjoyed reading this follow me on httpsbitlyaqiyk couplegoals love loved lovedogs loveforever loveislove lovelive lovely lovemakeup lovemylife lovenature lovequotes lovers loves lovestory lovethem loveu lovewhatyoudo loveyou loveyourbody meditation mindset momlife mylove poetry positivity relationshipgoals
# 2258                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning goodmorning goodlife dontgiveup win motivational motivationalquotes motivationalspeaker goodvibesonly vibes energy positivemindset positivity sucessmindset sucess sucessful quoteoftheday quotesaboutlife opportunites opportunityseeker growthopportunities growth goals winner
# 2259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                shout out to all the men of realsta who despite all odds and obstacles paved the way for themselves in this overambitious worldmay you get more strength and love you are doing the best you can and we are all proud of youwishing you a very happy international mens dayinternationalmensday mensday men mensrights meninist mentoo mgtow mra antifeminist equality antifeminism feminism redpill mensmentalhealthhimtoo mgtowisthefuture november equalrights metoo love redpilled mgtowforlife meninism boys positivity malepositivity
# 2260                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            inspiration innovation positivity management technology success
# 2261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          on the latest episode of the editing podcast denise and louise explain why they do not share content they dislike and why it is a good idea that you do not either if you see something that does not sit quite right with you do not spread it around  share something positive instead find out more about the hosts by visiting their websites  denise cowle httpslnkdingzuaewpa  louise harnby httpslnkdingvwmsuzediting podcast positivity theeditingpodcast
#
#            LABEL  TAGS
# 0        excited     1
# 1        excited     1
# 2        excited     1
# 3        excited     1
# 4        excited     1
# ...          ...   ...
# 2257  positivity     1
# 2258  positivity     1
# 2259  positivity     1
# 2260  positivity     1
# 2261  positivity     1
#
# [2255 rows x 4 columns]

# %%
unseen_complete_data['TAGS'].value_counts()
# Out:
# -1    1200
#  1    1055
# Name: TAGS, dtype: int64

# %%
from keras.preprocessing.text import Tokenizer
from keras_preprocessing.sequence import pad_sequences
#max_features = 2000
#tokenizer = Tokenizer(num_words = max_features, )
# tokenizer = Tokenizer()
# tokenizer.fit_on_texts(unseen_complete_data['POSTS'].values)
X = tokenizer.texts_to_sequences(unseen_complete_data['POSTS'].values)
X = pad_sequences(X, padding = 'post' , maxlen=100)
Y = pd.get_dummies(unseen_complete_data['TAGS']).values
#Y= complete_data['TAGS'].values

vocab_size = len(tokenizer.word_index)+1

# %%
# w2v test
te_w2v_embedding_matrix = np.zeros((vocab_size,300))
for word,i in tqdm(tokenizer.word_index.items()):
    embedding_value = word2vec_dict.get(word)
    te_w2v_embedding_matrix[i] = embedding_value
# Out:
# 100%|██████████| 92516/92516 [00:02<00:00, 37979.49it/s]

# %%
Y_test_new_unseen=[]
for val in Y:
  if val[0]==1:
    Y_test_new_unseen.append(0)
  else:
    Y_test_new_unseen.append(1)

# %%
from sklearn.metrics import classification_report

y_pred_unseen = stacked_gru_lstm.predict(X, batch_size=10, verbose=1)
y_pred_bool_unseen = np.argmax(y_pred_unseen, axis=1)

print(classification_report(Y_test_new_unseen, y_pred_bool_unseen))
# Out:
# 226/226 [==============================] - 4s 19ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      1200
#            1       0.85      0.84      0.84      1055
#
#     accuracy                           0.85      2255
#    macro avg       0.85      0.85      0.85      2255
# weighted avg       0.85      0.85      0.85      2255

# %%
del stacked_gru

# %% [markdown]
# **Twitter-roBERTa-base for Emotion Recognition**

# %%
# !pip install transformers

# %%
from transformers import AutoModelForSequenceClassification
from transformers import TFAutoModelForSequenceClassification
from transformers import AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

# Preprocess text (username and link placeholders)
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# Tasks:
# emoji, emotion, hate, irony, offensive, sentiment
# stance/abortion, stance/atheism, stance/climate, stance/feminist, stance/hillary

task='emotion'
MODEL = f"cardiffnlp/twitter-roberta-base-{task}"

tokenizer = AutoTokenizer.from_pretrained(MODEL)

# download label mapping
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels = [row[1] for row in csvreader if len(row) > 1]

# # PT
# model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# model.save_pretrained(MODEL)

# text = "Celebrating my promotion 😎"
# text = preprocess(text)
# encoded_input = tokenizer(text, return_tensors='pt')
# output = model(**encoded_input)
# scores = output[0][0].detach().numpy()
# scores = softmax(scores)
# Out:
# Downloading:   0%|          | 0.00/768 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
# TF
model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
model.save_pretrained(MODEL)
# Out:
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# All model checkpoint layers were used when initializing TFRobertaForSequenceClassification.
#
# All the layers of TFRobertaForSequenceClassification were initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-emotion.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaForSequenceClassification for predictions without further training.

# %%
complete_data.shape
# Out:
# (14376, 3)

# %%
y_pred = []
for text in tqdm(complete_data['POSTS']):
  encoded_input = tokenizer(text, return_tensors='tf')
  output = model(encoded_input)
  scores = output[0][0].numpy()
  scores = softmax(scores)
  if scores[0] + scores[3] >= 0.5:
    y_pred.append(0)
  elif scores[1] + scores[2] >= 0.5:
    y_pred.append(1)
  else:
    y_pred.append(2)
# Out:
# 100%|██████████| 14376/14376 [41:32<00:00,  5.77it/s]

# %%
# # TF
# # model = TFAutoModelForSequenceClassification.from_pretrained(MODEL)
# # model.save_pretrained(MODEL)

# text = "Celebrating my promotion 😎"
# encoded_input = tokenizer(text, return_tensors='tf')
# output = model(encoded_input)
# scores = output[0][0].numpy()
# scores = softmax(scores)
# ranking = np.argsort(scores)
# ranking = ranking[::-1]
# print(labels)
# print(scores)
# # for i in range(scores.shape[0]):
# #     l = labels[ranking[i]]
# #     s = scores[ranking[i]]
# #     print(f"{i+1}) {l} {np.round(float(s), 4)}")

# %%
# if scores[0] + scores[3] >= 0.5:
#   y_pred.append(0)
# elif scores[1] + scores[2] >= 0.5:
#   y_pred.append(1)
# else:
#   y_pred.append(2)

# %%
complete_data

# %%
# Function to convert score to sentiment
def to_sentiment(rating):
    
    rating = int(rating)
    
    # Convert to class
    if rating == -1:
        return 0
    else:
        return 1

# Apply to the dataset 
complete_data['SENT'] = complete_data.TAGS.apply(to_sentiment)

# %%
complete_data['SENT'].value_counts()
# Out:
# 0    8311
# 1    6065
# Name: SENT, dtype: int64

# %%
y_pred.count(1)
# Out:
# 9458

# %%
y_pred.count(0)
# Out:
# 4918

# %%
from sklearn.metrics import classification_report

# y_pred_unseen = stacked_gru_lstm.predict(X, batch_size=10, verbose=1)
# y_pred_bool_unseen = np.argmax(y_pred_unseen, axis=1)

print(classification_report(complete_data['SENT'].values, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.54      0.67      8311
#            1       0.59      0.93      0.72      6065
#
#     accuracy                           0.70     14376
#    macro avg       0.75      0.73      0.70     14376
# weighted avg       0.78      0.70      0.70     14376

# %% [markdown]
# **RoBERTa**

# %%
complete_data_bal.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              it is a gloomy day both here in chicago and on linkedin with the news of major layoffs   so just wanted to add some pawsitivity on everyone is feed of what my dog deems as a comfortable resting position on the couch  pawsup itsfriday
# 1  what to know more about matlab and matplotlib library in python here is my medium blog that will help you to understand matplotlib in an easy manner i have planned to write this blog in  different parts this is the basic part and the intro of it  for guys who do know what matplotlib is about here is a quick glimpse of it  matplotlib is an amazing visualization library in python for d plots of arrays matplotlib is a multiplatform data visualization library built on numpy arrays and designed to work with the broader scipy stack it was introduced by john hunter in the year  one of the greatest benefits of visualization is that it allows us visual access to huge amounts of data in easily digestible visuals matplotlib consists of several plots like line bar scatter histogram etcto know much more about how it works how we can install and use it and how we can use it to visualize large data please feel free to read the article feel free to connect gokul arumugamtake it if you like and drop it if you do not python data datavisualization work like visualization bigdataanalytics dataanalytics jupyternotebook matplotlib job hiring layoffs datascience dataanalyst bigdata bigdatatechnologies ai ml mlops machinelearning algorithms dsa fullstackdeveloper dataanalist database help
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      freedom women power iran protests
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            iranian phd candidate nasringhaderi beaten during protests dies father says she died of flu
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 httpslnkdingjbsejw sad
#
#       LABEL  TAGS  SENT
# 0   layoffs    -1     0
# 1   layoffs    -1     0
# 2  protests    -1     0
# 3  protests    -1     0
# 4       sad    -1     0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(complete_data_bal['POSTS'].values, complete_data_bal['SENT'].values, test_size = 0.20, random_state = 42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (9704,) (9704,)
# (2426,) (2426,)

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 14.8 MB/s
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 67.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 71.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.0 tokenizers-0.13.2 transformers-4.24.0

# %%
# Importing the libraries needed
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import seaborn as sns
import transformers
import json
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader
from transformers import RobertaModel, RobertaTokenizer
import logging
logging.basicConfig(level=logging.ERROR)

# %%
# Setting up the device for GPU usage

from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
# Defining some key variables that will be used later on in the training
MAX_LEN = 256
TRAIN_BATCH_SIZE = 8
VALID_BATCH_SIZE = 4
# EPOCHS = 1
LEARNING_RATE = 1e-05
tokenizer = RobertaTokenizer.from_pretrained('roberta-base', truncation=True, do_lower_case=True)
# Out:
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]

# %%
class SentimentData(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.text = dataframe.POSTS
        self.targets = self.data.SENT
        self.max_len = max_len

    def __len__(self):
        return len(self.text)

    def __getitem__(self, index):
        text = str(self.text[index])
        text = " ".join(text.split())

        inputs = self.tokenizer.encode_plus(
            text,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            pad_to_max_length=True,
            return_token_type_ids=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]


        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long),
            'targets': torch.tensor(self.targets[index], dtype=torch.float)
        }

# %%
complete_data_bal

# %%
train_size = 0.8
train_data=complete_data_bal.sample(frac=train_size,random_state=200)
test_data=complete_data_bal.drop(train_data.index).reset_index(drop=True)
train_data = train_data.reset_index(drop=True)


print("FULL Dataset: {}".format(complete_data_bal.shape))
print("TRAIN Dataset: {}".format(train_data.shape))
print("TEST Dataset: {}".format(test_data.shape))

training_set = SentimentData(train_data, tokenizer, MAX_LEN)
testing_set = SentimentData(test_data, tokenizer, MAX_LEN)
# Out:
# FULL Dataset: (12130, 4)
# TRAIN Dataset: (9704, 4)
# TEST Dataset: (2426, 4)

# %%
train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

training_loader = DataLoader(training_set, **train_params)
testing_loader = DataLoader(testing_set, **test_params)

# %%
class RobertaClass(torch.nn.Module):
    def __init__(self):
        super(RobertaClass, self).__init__()
        self.l1 = RobertaModel.from_pretrained("roberta-base")
        self.pre_classifier = torch.nn.Linear(768, 768)
        self.dropout = torch.nn.Dropout(0.3)
        self.classifier = torch.nn.Linear(768, 2)

    def forward(self, input_ids, attention_mask, token_type_ids):
        output_1 = self.l1(input_ids=input_ids, attention_mask=attention_mask, token_type_ids=token_type_ids)
        hidden_state = output_1[0]
        pooler = hidden_state[:, 0]
        pooler = self.pre_classifier(pooler)
        pooler = torch.nn.ReLU()(pooler)
        pooler = self.dropout(pooler)
        output = self.classifier(pooler)
        return output

# %%
model = RobertaClass()
model.to(device)
# Out:
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-f66db942c668> in <module>
# ----> 1 model = RobertaClass()
#       2 model.to(device)
#
# <ipython-input-23-d15d60494efa> in __init__(self)
#       2     def __init__(self):
#       3         super(RobertaClass, self).__init__()
# ----> 4         self.l1 = RobertaModel.from_pretrained("roberta-base")
#       5         self.pre_classifier = torch.nn.Linear(768, 768)
#       6         self.dropout = torch.nn.Dropout(0.3)
#
# /usr/local/lib/python3.7/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#    2089                         _commit_hash=commit_hash,
#    2090                     )
# -> 2091                     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    2092
#    2093                     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#
# /usr/local/lib/python3.7/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, use_auth_token, revision, local_files_only, subfolder, user_agent, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash)
#     418             resume_download=resume_download,
#     419             use_auth_token=use_auth_token,
# --> 420             local_files_only=local_files_only,
#     421         )
#     422
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     122             )
#     123
# --> 124         return fn(*args, **kwargs)
#     125
#     126     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout)
#    1243                 proxies=proxies,
#    1244                 resume_size=resume_size,
# -> 1245                 headers=headers,
#    1246             )
#    1247
#
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, timeout, max_retries)
#     491         disable=bool(logger.getEffectiveLevel() == logging.NOTSET),
#     492     )
# --> 493     for chunk in r.iter_content(chunk_size=1024):
#     494         if chunk:  # filter out keep-alive new chunks
#     495             progress.update(len(chunk))
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     494         else:
#     495             while not is_fp_closed(self._fp):
# --> 496                 data = self.read(amt=amt, decode_content=decode_content)
#     497
#     498                 if data:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     435         data = None
#     436
# --> 437         with self._error_catcher():
#     438             if amt is None:
#     439                 # cStringIO doesn't like amt=None
#
# KeyboardInterrupt:

# %%
# Creating the loss function and optimizer
loss_function = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(params =  model.parameters(), lr=LEARNING_RATE)

# %%
def calcuate_accuracy(preds, targets):
    n_correct = (preds==targets).sum().item()
    return n_correct

# %%
# Defining the training function on the 80% of the dataset for tuning the distilbert model

def train(epoch):
    tr_loss = 0
    n_correct = 0
    nb_tr_steps = 0
    nb_tr_examples = 0
    model.train()
    for _,data in tqdm(enumerate(training_loader, 0)):
        ids = data['ids'].to(device, dtype = torch.long)
        mask = data['mask'].to(device, dtype = torch.long)
        token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
        targets = data['targets'].to(device, dtype = torch.long)

        outputs = model(ids, mask, token_type_ids)
        loss = loss_function(outputs, targets)
        tr_loss += loss.item()
        big_val, big_idx = torch.max(outputs.data, dim=1)
        n_correct += calcuate_accuracy(big_idx, targets)

        nb_tr_steps += 1
        nb_tr_examples+=targets.size(0)
        
        if _%5000==0:
            loss_step = tr_loss/nb_tr_steps
            accu_step = (n_correct*100)/nb_tr_examples 
            print(f"Training Loss per 5000 steps: {loss_step}")
            print(f"Training Accuracy per 5000 steps: {accu_step}")

        optimizer.zero_grad()
        loss.backward()
        # # When using GPU
        optimizer.step()

    print(f'The Total Accuracy for Epoch {epoch}: {(n_correct*100)/nb_tr_examples}')
    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = (n_correct*100)/nb_tr_examples
    print(f"Training Loss Epoch: {epoch_loss}")
    print(f"Training Accuracy Epoch: {epoch_accu}")

    return

# %%
EPOCHS = 10
for epoch in range(EPOCHS):
    train(epoch)

# %%
def valid(model, testing_loader):
    model.eval()
    n_correct = 0; n_wrong = 0; total = 0; tr_loss=0; nb_tr_steps=0; nb_tr_examples=0
    with torch.no_grad():
        for _, data in tqdm(enumerate(testing_loader, 0)):
            ids = data['ids'].to(device, dtype = torch.long)
            mask = data['mask'].to(device, dtype = torch.long)
            token_type_ids = data['token_type_ids'].to(device, dtype=torch.long)
            targets = data['targets'].to(device, dtype = torch.long)
            outputs = model(ids, mask, token_type_ids).squeeze()
            loss = loss_function(outputs, targets)
            tr_loss += loss.item()
            big_val, big_idx = torch.max(outputs.data, dim=1)
            n_correct += calcuate_accuracy(big_idx, targets)

            nb_tr_steps += 1
            nb_tr_examples+=targets.size(0)
            
            if _%5000==0:
                loss_step = tr_loss/nb_tr_steps
                accu_step = (n_correct*100)/nb_tr_examples
                print(f"Validation Loss per 100 steps: {loss_step}")
                print(f"Validation Accuracy per 100 steps: {accu_step}")
    epoch_loss = tr_loss/nb_tr_steps
    epoch_accu = (n_correct*100)/nb_tr_examples
    print(f"Validation Loss Epoch: {epoch_loss}")
    print(f"Validation Accuracy Epoch: {epoch_accu}")
    
    return epoch_accu

# %%
acc = valid(model, testing_loader)
print("Accuracy on test data = %0.2f%%" % acc)
# Out:
# 3it [00:00, 23.17it/s]
# Validation Loss per 100 steps: 0.6547155380249023
# Validation Accuracy per 100 steps: 75.0
# 5004it [03:13, 25.87it/s]
# Validation Loss per 100 steps: 0.736690901120772
# Validation Accuracy per 100 steps: 69.22115576884623
# 7803it [05:01, 25.89it/s]
# Validation Loss Epoch: 0.7332612214877096
# Validation Accuracy Epoch: 69.46687171600666
# Accuracy on test data = 69.47%

# %%
output_model_file = '/content/gdrive/MyDrive/group_17/pytorch_roberta_sentiment.bin'
# output_vocab_file = './'

model_to_save = model
torch.save(model_to_save, output_model_file)
# tokenizer.save_vocabulary(output_vocab_file)

print('All files saved')
print('This tutorial is completed')
# Out:
# All files saved
# This tutorial is completed

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
import tokenizers
from transformers import RobertaTokenizer, TFRobertaModel

# %%
MODEL_NAME = 'roberta-base'
MAX_LEN = 256
ARTIFACTS_PATH = '../artifacts/'

BATCH_SIZE = 8
EPOCHS = 10

# %%
def roberta_encode(texts, tokenizer):
    ct = len(texts)
    input_ids = np.ones((ct, MAX_LEN), dtype='int32')
    attention_mask = np.zeros((ct, MAX_LEN), dtype='int32')
    token_type_ids = np.zeros((ct, MAX_LEN), dtype='int32') # Not used in text classification

    for k, text in enumerate(texts):
        # Tokenize
        tok_text = tokenizer.tokenize(text)
        
        # Truncate and convert tokens to numerical IDs
        enc_text = tokenizer.convert_tokens_to_ids(tok_text[:(MAX_LEN-2)])
        
        input_length = len(enc_text) + 2
        input_length = input_length if input_length < MAX_LEN else MAX_LEN
        
        # Add tokens [CLS] and [SEP] at the beginning and the end
        input_ids[k,:input_length] = np.asarray([0] + enc_text + [2], dtype='int32')
        
        # Set to 1s in the attention input
        attention_mask[k,:input_length] = 1

    return {
        'input_word_ids': input_ids,
        'input_mask': attention_mask,
        'input_type_ids': token_type_ids
    }

# %%
# Import tokenizer from HuggingFace
tokenizer = RobertaTokenizer.from_pretrained(MODEL_NAME)

# %%
X_data = complete_data_bal[['POSTS']].to_numpy().reshape(-1)
y_data = complete_data_bal[['SENT']].to_numpy().reshape(-1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size = 0.20, random_state = 42)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (9704,) (9704,)
# (2426,) (2426,)

# %%
X_train = roberta_encode(X_train, tokenizer)
X_test = roberta_encode(X_test, tokenizer)

y_train = np.asarray(y_train, dtype='int32')
y_test = np.asarray(y_test, dtype='int32')

# %%
# !nvidia-smi
# Out:
# Tue Nov 29 05:32:52 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
def build_model(n_categories):
      input_word_ids = tf.keras.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_word_ids')
      input_mask = tf.keras.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_mask')
      input_type_ids = tf.keras.Input(shape=(MAX_LEN,), dtype=tf.int32, name='input_type_ids')

      # Import RoBERTa model from HuggingFace
      roberta_model = TFRobertaModel.from_pretrained(MODEL_NAME)
      x = roberta_model(input_word_ids, attention_mask=input_mask, token_type_ids=input_type_ids)

      # Huggingface transformers have multiple outputs, embeddings are the first one,
      # so let's slice out the first position
      x = x[0]

      x = tf.keras.layers.Dropout(0.1)(x)
      x = tf.keras.layers.Flatten()(x)
      x = tf.keras.layers.Dense(256, activation='relu')(x)
      x = tf.keras.layers.Dense(n_categories, activation='softmax')(x)

      model = tf.keras.Model(inputs=[input_word_ids, input_mask, input_type_ids], outputs=x)
      model.compile(
          optimizer=tf.keras.optimizers.Adam(lr=1e-5),
          loss='sparse_categorical_crossentropy',
          metrics=['accuracy'])

      return model

# %%
model = build_model(2)
model.summary()
# Out:
# Some layers from the model checkpoint at roberta-base were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at roberta-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_word_ids (InputLayer)    [(None, 256)]        0           []
#
#  input_mask (InputLayer)        [(None, 256)]        0           []
#
#  input_type_ids (InputLayer)    [(None, 256)]        0           []
#
#  tf_roberta_model_1 (TFRobertaM  TFBaseModelOutputWi  124645632  ['input_word_ids[0][0]',
#  odel)                          thPoolingAndCrossAt               'input_mask[0][0]',
#                                 tentions(last_hidde               'input_type_ids[0][0]']
#                                 n_state=(None, 256,
#                                  768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  dropout_75 (Dropout)           (None, 256, 768)     0           ['tf_roberta_model_1[0][0]']
#
#  flatten_1 (Flatten)            (None, 196608)       0           ['dropout_75[0][0]']
#
#  dense_2 (Dense)                (None, 256)          50331904    ['flatten_1[0][0]']
#
#  dense_3 (Dense)                (None, 2)            514         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 174,978,050
# Trainable params: 174,978,050
# Non-trainable params: 0
# __________________________________________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint('/content/gdrive/MyDrive/group_17/roberta_256_8.h5', monitor='val_accuracy', save_best_only=True, verbose=1)
earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, verbose=1)

train_history = model.fit(
    X_train, y_train, 
    epochs=10,
    validation_split = 0.2,
    callbacks=[checkpoint, earlystopping],
    batch_size=8,
    verbose=1)
# Out:
# Epoch 1/10
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_2/roberta/pooler/dense/kernel:0', 'tf_roberta_model_2/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_roberta_model_2/roberta/pooler/dense/kernel:0', 'tf_roberta_model_2/roberta/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 971/971 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8508
# Epoch 1: val_accuracy improved from -inf to 0.88769, saving model to /content/gdrive/MyDrive/group_17/roberta_256_8.h5
# 971/971 [==============================] - 557s 518ms/step - loss: 0.3034 - accuracy: 0.8508 - val_loss: 0.2122 - val_accuracy: 0.8877
# Epoch 2/10
# 971/971 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9188
# Epoch 2: val_accuracy improved from 0.88769 to 0.90675, saving model to /content/gdrive/MyDrive/group_17/roberta_256_8.h5
# 971/971 [==============================] - 512s 527ms/step - loss: 0.1737 - accuracy: 0.9188 - val_loss: 0.1958 - val_accuracy: 0.9067
# Epoch 3/10
# 971/971 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9384
# Epoch 3: val_accuracy improved from 0.90675 to 0.90829, saving model to /content/gdrive/MyDrive/group_17/roberta_256_8.h5
# 971/971 [==============================] - 511s 526ms/step - loss: 0.1290 - accuracy: 0.9384 - val_loss: 0.2231 - val_accuracy: 0.9083
# Epoch 4/10
# 971/971 [==============================] - ETA: 0s - loss: 0.0944 - accuracy: 0.9606
# Epoch 4: val_accuracy improved from 0.90829 to 0.91036, saving model to /content/gdrive/MyDrive/group_17/roberta_256_8.h5
# 971/971 [==============================] - 513s 528ms/step - loss: 0.0944 - accuracy: 0.9606 - val_loss: 0.2481 - val_accuracy: 0.9104
# Epoch 5/10
# 971/971 [==============================] - ETA: 0s - loss: 0.0683 - accuracy: 0.9695
# Epoch 5: val_accuracy did not improve from 0.91036
# 971/971 [==============================] - 492s 507ms/step - loss: 0.0683 - accuracy: 0.9695 - val_loss: 0.3685 - val_accuracy: 0.9047
# Epoch 6/10
# 971/971 [==============================] - ETA: 0s - loss: 0.0643 - accuracy: 0.9744
# Epoch 6: val_accuracy did not improve from 0.91036
# 971/971 [==============================] - 491s 506ms/step - loss: 0.0643 - accuracy: 0.9744 - val_loss: 0.4355 - val_accuracy: 0.9031
# Epoch 7/10
# 971/971 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9789
# Epoch 7: val_accuracy improved from 0.91036 to 0.91293, saving model to /content/gdrive/MyDrive/group_17/roberta_256_8.h5
# 971/971 [==============================] - 510s 526ms/step - loss: 0.0480 - accuracy: 0.9789 - val_loss: 0.3858 - val_accuracy: 0.9129
# Epoch 8/10
# 971/971 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9793
# Epoch 8: val_accuracy did not improve from 0.91293
# 971/971 [==============================] - 492s 506ms/step - loss: 0.0494 - accuracy: 0.9793 - val_loss: 0.4526 - val_accuracy: 0.9057
# Epoch 9/10
# 895/971 [==========================>...] - ETA: 35s - loss: 0.0408 - accuracy: 0.9823

# %%
model.load_weights('/content/gdrive/MyDrive/group_17/roberta_256_16.h5')
test_pred = model.predict(X_test)
# Out:
# 95/95 [==============================] - 55s 536ms/step

# %%
test_pred
# Out:
# array([[6.8379500e-06, 9.9999321e-01],
#        [9.9942917e-01, 5.7078176e-04],
#        [5.1425787e-04, 9.9948573e-01],
#        ...,
#        [9.9992931e-01, 7.0655376e-05],
#        [5.5594487e-06, 9.9999440e-01],
#        [4.1793199e-05, 9.9995816e-01]], dtype=float32)

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(test_pred, axis=1)
y_true = np.argmax(test_labels, axis=1)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96      1534
#            1       0.98      0.95      0.96      1499
#
#     accuracy                           0.96      3033
#    macro avg       0.96      0.96      0.96      3033
# weighted avg       0.96      0.96      0.96      3033

# %% [markdown]
# **Testing the model on completely new/unseen data**

# %%
path = "/content/gdrive/MyDrive/group_17/unseen_test_data"
dir_list = os.listdir(path)
pd.set_option('display.max_colwidth', None)

# %%
all_lines_list=list()
labels_list=list()
for filename in dir_list:
    file_extension_val=filename.split('.')
    file_extension=file_extension_val[1]
    if(file_extension=='txt'):
        label=filename.split('_')
        label=label[2]
        label=label.split('.')
        label=label[0]
        labels_list.append(label)
        # with open("/content/gdrive/MyDrive/Colab Notebooks/Unseen_test_data/"+filename, encoding='unicode_escape') as file_ptr:
        with open(path + "/" + filename, encoding='utf-8') as file_ptr:
            lines_temp = list()
            for line in file_ptr:
                if(line.strip()!="-----------------------------"):
                    lines_temp.append(line)
            all_lines_list.append(lines_temp)

# %%
df_posts=pd.DataFrame()
labels_global_list=list()
label_index=0
for lst in all_lines_list:
    df_temp = pd.DataFrame(lst)
    df_posts=df_posts.append(df_temp,ignore_index=True,)
#     label_length=len(lst)
    for i in range(len(lst)):
        labels_global_list.append(labels_list[label_index])
    label_index=label_index+1
    
df_labels = pd.DataFrame(labels_global_list)

# %%
unseen_complete_data = pd.concat([df_posts, df_labels], axis=1)
unseen_complete_data.columns = ['POSTS', 'LABEL']
unseen_complete_data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Does Excel run on Mac? You bet. So do Word, PowerPoint, and all the apps you need.\n
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  I'm about to start a new role at Capgemini and containing myself is a real issue.Don't ask 😌#excited\n
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 New chapter. #excited\n
# 3     Flying away from the Nest and setting off for new adventures on the other side of the planet 🗺️This day marks a couple of important milestones:-         My first post ever on LinkedIn 🚀 (Is this really a milestone?)-         My last day working at Nestlé-         The beginning of a new and exciting journey 😍I am thrilled to announce that I’ll be moving to New Zealand as of February 2023 (#excited). Driven by the willingness to enrich ourselves as individuals, to go out of our comfort zone, to experience a new professional and personal environment, and to discover new outdoor experiences, my partner and I have decided to take that step. And why not?Since I graduated from ISIPCA in 2014, the past decade at Nestlé (wow, this sounds like a lot) which started with a 2-years internship has been incredibly rich and I feel very lucky for all the projects and experiences I went through. I met inspiring people and worked on innovative projects. From being part of the Nestlé R&D accelerator to the nesQino™️ journey, and plenty of other initiatives, I enjoyed the diversity of projects, activities, and challenges.The journey has also sometimes been punctuated with some doubts and questions, which were essential to go the extra mile. Those who know me know that I am always eager to learn new things. I don’t know yet what will come next, and I am very curious to see what the future will bring… The next two months will be busy organizing the move (and solving admin stuff), enjoying time with family and friends, recharging, and settling in New Zealand. I’ll be available for work as of February 2023 and I can’t wait to discover what New Zealand has to offer. I would love to start discussions about expatriation experiences, tips about New Zealand, potential work opportunities (including remote), …\n
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          #Excited about the great things to come from this partnership.  Gracias to my Omnicom Media Group familia (Geoffrey Calabrese, Kelly Metz, Amy Darwish) and TelevisaUnivision (Daniel Aversano, Richard Bertodatti) for making this happen! #multiculturalmarketing https://lnkd.in/eVpbW7CU\n
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 2579                                                                                                                                                                                                                                                                                                                                                                                                                  Allowing Ourselves To Be Nurtured Let yourself be nurtured and loved.Let people be there for you.Allow yourself to be held when it would feel good.Let someone listen to you, support and encourage you when you need that.Receive comfort from someone's physical presence when you need that. Allow yourself to be supported emotionally and cared about.For too long, we've stood in the background, attending to the needs of others and claiming we have no needs of our own.We've shut off, for too long, the part of us that longs to be nurtured.It is time, now, to claim those needs, identify them, and understand that we deserve to have them met. What are our needs? What would feel good? What kinds of ways would we like others to nurture and support us?The clearer we can be about our needs, the greater the possibility they will be met.Hugs. A listening ear. Support. Encouragement.The physical and emotional presence of people who care about us.Doesn't that sound good? Tempting?No matter how old or successful we are,  we never outgrow our need for nurturing and love.Enjoyed reading this? Follow me on: https://bit.ly/3AqIY6k #couplegoals #love #loved #lovedogs #loveforever #loveislove #lovelive #lovely #lovemakeup #lovemylife #lovenature #lovequotes #lovers #loves #lovestory #lovethem #loveu #lovewhatyoudo #loveyou #loveyourbody #meditation #mindset #momlife #mylove #poetry #positivity #relationshipgoals\n
# 2580                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Good morning 😊#goodmorning #goodlife #dontgiveup #win #motivational #motivationalquotes #motivationalspeaker #goodvibesonly #vibes #energy #positivemindset #positivity #sucessmindset #sucess #sucessful #quoteoftheday #quotesaboutlife #opportunites #opportunityseeker #growthopportunities #growth #goals #winner\n
# 2581                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Shout out to all the men of REALSTA who despite all odds and obstacles paved the way for themselves in this over-ambitious world. May you get more strength and love. You are doing the best you can and we are all proud of you. Wishing you a very Happy International Men's Day!#internationalmensday #mensday #men #mensrights #meninist #mentoo #mgtow #mra #antifeminist #equality #antifeminism #feminism #redpill #mensmentalhealth #himtoo #mgtowisthefuture #november #equalrights #metoo #love #redpilled #mgtowforlife #meninism #boys #positivity #malepositivity\n
# 2582                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              #inspiration #innovation #positivity #management #technology #success\n
# 2583                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            On the latest episode of The Editing Podcast, Denise and Louise explain why they don’t share content they dislike and why it’s a good idea that you don’t, either. If you see something that doesn’t sit quite right with you, don’t spread it around — share something positive instead. 🌻Find out more about the hosts by visiting their websites. – Denise Cowle: https://lnkd.in/gzuAEwPA – Louise Harnby: https://lnkd.in/gV7wMsuZ#editing #podcast #positivity #theeditingpodcast\n
#
#            LABEL
# 0        excited
# 1        excited
# 2        excited
# 3        excited
# 4        excited
# ...          ...
# 2579  positivity
# 2580  positivity
# 2581  positivity
# 2582  positivity
# 2583  positivity
#
# [2584 rows x 2 columns]

# %%
#convert to lowercase
unseen_complete_data['POSTS']=unseen_complete_data['POSTS'].str.lower()

# %%
#remove html content
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].apply(lambda x: re.split('<[^<>]*>', str(x))[0])

# %%
def contr(post_text):
     posts_body_list=[]
     for r in post_text:
         decontract_posts_body = contractions.fix(r)
         r = ''.join(decontract_posts_body)
         r = re.sub("\s\s+", " ", r) # remove extra spaces
         posts_body_list.append(r)
     return posts_body_list

# %%
unseen_complete_data['POSTS']=contr(unseen_complete_data['POSTS'].values)

# %%
#remove non-alphabetical values
unseen_complete_data['POSTS'] = unseen_complete_data['POSTS'].replace('[^a-zA-Z ]', '', regex=True)

# %%
import numpy as np
unseen_complete_data['TAGS']=np.where( (unseen_complete_data['LABEL']=='excited') | (unseen_complete_data['LABEL']=='hiring') | (unseen_complete_data['LABEL']=='positivity') | (unseen_complete_data['LABEL']=='positivevibes') | (unseen_complete_data['LABEL']=='grateful') | (unseen_complete_data['LABEL']=='newjob') | (unseen_complete_data['LABEL']=='blessed') | (unseen_complete_data['LABEL']=='happy') | (unseen_complete_data['LABEL']=='lmao') | (unseen_complete_data['LABEL']=='funny') | (unseen_complete_data['LABEL']=='fun') | (unseen_complete_data['LABEL']=='lol') , 1, -1)

# %%
unseen_complete_data=unseen_complete_data.drop_duplicates(keep='last').reset_index()

# %%
unseen_complete_data['POSTS'].replace('', np.nan, inplace=True)
unseen_complete_data.dropna(subset=['POSTS'], inplace=True)
unseen_complete_data
# Out:
#       index  \
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
# ...     ...
# 2257   2579
# 2258   2580
# 2259   2581
# 2260   2582
# 2261   2583
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           POSTS  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 does excel run on mac you bet so do word powerpoint and all the apps you need
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           i am about to start a new role at capgemini and containing myself is a real issuedo not ask excited
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           new chapter excited
# 3     flying away from the nest and setting off for new adventures on the other side of the planet this day marks a couple of important milestones my first post ever on linkedin  is this really a milestone my last day working at nestl the beginning of a new and exciting journey i am thrilled to announce that i will be moving to new zealand as of february  excited driven by the willingness to enrich ourselves as individuals to go out of our comfort zone to experience a new professional and personal environment and to discover new outdoor experiences my partner and i have decided to take that step and why notsince i graduated from isipca in  the past decade at nestl wow this sounds like a lot which started with a years internship has been incredibly rich and i feel very lucky for all the projects and experiences i went through i met inspiring people and worked on innovative projects from being part of the nestl rd accelerator to the nesqino journey and plenty of other initiatives i enjoyed the diversity of projects activities and challengesthe journey has also sometimes been punctuated with some doubts and questions which were essential to go the extra mile those who know me know that i am always eager to learn new things i do not know yet what will come next and i am very curious to see what the future will bring the next two months will be busy organizing the move and solving admin stuff enjoying time with family and friends recharging and settling in new zealand i will be available for work as of february  and i cannot wait to discover what new zealand has to offer i would love to start discussions about expatriation experiences tips about new zealand potential work opportunities including remote
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    excited about the great things to come from this partnership gracias to my omnicom media group familia geoffrey calabrese kelly metz amy darwish and televisaunivision daniel aversano richard bertodatti for making this happen multiculturalmarketing httpslnkdinevpbwcu
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 2257                                                                                                                                                                                                                                                                                                                                                                                           allowing ourselves to be nurturedlet yourself be nurtured and lovedlet people be there for youallow yourself to be held when it would feel goodlet someone listen to you support and encourage you when you need thatreceive comfort from someone is physical presence when you need that allow yourself to be supported emotionally and cared aboutfor too long we have stood in the background attending to the needs of others and claiming we have no needs of our ownwe have shut off for too long the part of us that longs to be nurturedit is time now to claim those needs identify them and understand that we deserve to have them metwhat are our needs what would feel good what kinds of ways would we like others to nurture and support usthe clearer we can be about our needs the greater the possibility they will be methugs a listening ear support encouragementthe physical and emotional presence of people who care about usdoes not that sound good temptingno matter how old or successful we are we never outgrow our need for nurturing and loveenjoyed reading this follow me on httpsbitlyaqiyk couplegoals love loved lovedogs loveforever loveislove lovelive lovely lovemakeup lovemylife lovenature lovequotes lovers loves lovestory lovethem loveu lovewhatyoudo loveyou loveyourbody meditation mindset momlife mylove poetry positivity relationshipgoals
# 2258                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             good morning goodmorning goodlife dontgiveup win motivational motivationalquotes motivationalspeaker goodvibesonly vibes energy positivemindset positivity sucessmindset sucess sucessful quoteoftheday quotesaboutlife opportunites opportunityseeker growthopportunities growth goals winner
# 2259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                shout out to all the men of realsta who despite all odds and obstacles paved the way for themselves in this overambitious worldmay you get more strength and love you are doing the best you can and we are all proud of youwishing you a very happy international mens dayinternationalmensday mensday men mensrights meninist mentoo mgtow mra antifeminist equality antifeminism feminism redpill mensmentalhealthhimtoo mgtowisthefuture november equalrights metoo love redpilled mgtowforlife meninism boys positivity malepositivity
# 2260                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            inspiration innovation positivity management technology success
# 2261                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          on the latest episode of the editing podcast denise and louise explain why they do not share content they dislike and why it is a good idea that you do not either if you see something that does not sit quite right with you do not spread it around  share something positive instead find out more about the hosts by visiting their websites  denise cowle httpslnkdingzuaewpa  louise harnby httpslnkdingvwmsuzediting podcast positivity theeditingpodcast
#
#            LABEL  TAGS
# 0        excited     1
# 1        excited     1
# 2        excited     1
# 3        excited     1
# 4        excited     1
# ...          ...   ...
# 2257  positivity     1
# 2258  positivity     1
# 2259  positivity     1
# 2260  positivity     1
# 2261  positivity     1
#
# [2255 rows x 4 columns]

# %%
unseen_complete_data['TAGS'].value_counts()
# Out:
# -1    1200
#  1    1055
# Name: TAGS, dtype: int64

# %%
# Function to convert score to sentiment
def to_sentiment(rating):
    
    rating = int(rating)
    
    # Convert to class
    if rating == -1:
        return 0
    else:
        return 1

# Apply to the dataset 
unseen_complete_data['SENT'] = unseen_complete_data.TAGS.apply(to_sentiment)

# %%
X_data = unseen_complete_data[['POSTS']].to_numpy().reshape(-1)
y_data = unseen_complete_data[['SENT']].to_numpy().reshape(-1)

# %%
# X_train = roberta_encode(X_train, tokenizer)
X_test = roberta_encode(X_data, tokenizer)

# y_train = np.asarray(y_train, dtype='int32')
y_test = np.asarray(y_data, dtype='int32')

# %%
model.load_weights('/content/gdrive/MyDrive/group_17/roberta_256_8.h5')
test_pred = model.predict(X_test)
# Out:
# 71/71 [==============================] - 1340s 19s/step

# %%
y_test
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
test_pred
# Out:
# array([[7.1102604e-02, 9.2889738e-01],
#        [2.9401576e-10, 9.9999994e-01],
#        [3.3125003e-13, 9.9999994e-01],
#        ...,
#        [8.6967535e-03, 9.9130321e-01],
#        [1.1193059e-08, 1.0000000e+00],
#        [2.6949522e-08, 1.0000000e+00]], dtype=float32)

# %%
unseen_labels = tf.keras.utils.to_categorical(unseen_complete_data['SENT'].values, num_classes=2)
# test_labels = tf.keras.utils.to_categorical(y_test, num_classes=2)

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(test_pred, axis=1)
y_true = np.argmax(unseen_labels, axis=1)

print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.84      0.88      1200
#            1       0.83      0.92      0.88      1055
#
#     accuracy                           0.88      2255
#    macro avg       0.88      0.88      0.88      2255
# weighted avg       0.88      0.88      0.88      2255
